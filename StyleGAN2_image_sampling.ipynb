# %% [markdown]
# # StyleGAN2: sampling images with a trained model
#
# References:
# - this notebook: https://github.com/woctezuma/steam-stylegan2
# - the original StyleGAN2 repository: https://github.com/NVlabs/stylegan2
# - my fork of StyleGAN2: https://github.com/woctezuma/stylegan2

# %% [markdown]
# ## Installing StyleGAN2

# %% [markdown]
# ### The official StyleGAN2 implementation

# %%
# %cd /content/
# Out:
# /content

# %% [markdown]
# Clone the official implementation:

# %%
# !rm -rf stylegan2/
# !git clone https://github.com/NVlabs/stylegan2.git
# Out:
# Cloning into 'stylegan2'...
# remote: Enumerating objects: 120, done.
# remote: Total 120 (delta 0), reused 0 (delta 0), pack-reused 120
# Receiving objects: 100% (120/120), 583.49 KiB | 13.89 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
pushd
# Out:
# ['/content']

# %%
# %cd stylegan2/
# Out:
# /content/stylegan2

# %%
# !nvcc test_nvcc.cu -o test_nvcc -run
# Out:
# CPU says hello.
# GPU says hello.

# %%
popd
# Out:
# /content
# popd -> /content

# %% [markdown]
# ## Mounting Google Drive

# %%
# !pip install Google-Colab-Transfer
# Out:
# Requirement already satisfied: Google-Colab-Transfer in /usr/local/lib/python3.6/dist-packages (0.1.4)

# %%
import colab_transfer

colab_path = colab_transfer.get_path_to_home_of_local_machine()
drive_path = colab_transfer.get_path_to_home_of_google_drive()

print('Disk of the virtual matchine: {}'.format(colab_path))
print('Google Drive: {}'.format(drive_path))
# Out:
# Disk of the virtual matchine: /content/
# Google Drive: /content/drive/My Drive/

# %%
colab_transfer.mount_google_drive()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## Generating images

# %% [markdown]
# ### Load the snapshots from Google Drive

# %% [markdown]
# The checkpoint corresponding to a fully trained model is imported from Google Drive.
#
# This checkpoint is assumed to be called `network-final.pkl`. If this is not the case, please ensure to rename the checkpoint accordingly.

# %%
result_root_folder = 'results/'

# %%
result_folder_name_to_load = '00055-stylegan2-steam-1gpu-config-e'

# %%
colab_transfer.copy_folder(result_folder_name_to_load,
                           source=drive_path + result_root_folder,
                           destination=colab_path + result_root_folder)
# Out:
# Copying /content/drive/My Drive/results/00055-stylegan2-steam-1gpu-config-e to /content/results/00055-stylegan2-steam-1gpu-config-e

# %% [markdown]
# ### Generate images, using the final snapshot

# %% [markdown]
# Generate 1000 random images:

# %% [markdown]
# #### Without truncation

# %%
# !python stylegan2/run_generator.py generate-images \
  --seeds=0-999 \
  --truncation-psi=1.0 \
  --network=results/{result_folder_name_to_load}/network-final.pkl \
  --result-dir='/content/drive/My Drive/results' \
# Out:
# Local submit - run_dir: /content/drive/My Drive/results/00056-generate-images
# dnnlib: Running run_generator.generate_images() on localhost...
# Loading networks from "results/00055-stylegan2-steam-1gpu-config-e/network-final.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# Generating image for seed 0 (0/1000) ...
# Generating image for seed 1 (1/1000) ...
# Generating image for seed 2 (2/1000) ...
# Generating image for seed 3 (3/1000) ...
# Generating image for seed 4 (4/1000) ...
# Generating image for seed 5 (5/1000) ...
# Generating image for seed 6 (6/1000) ...
# Generating image for seed 7 (7/1000) ...
# Generating image for seed 8 (8/1000) ...
# Generating image for seed 9 (9/1000) ...
# Generating image for seed 10 (10/1000) ...
# Generating image for seed 11 (11/1000) ...
# Generating image for seed 12 (12/1000) ...
# Generating image for seed 13 (13/1000) ...
# Generating image for seed 14 (14/1000) ...
# Generating image for seed 15 (15/1000) ...
# Generating image for seed 16 (16/1000) ...
# Generating image for seed 17 (17/1000) ...
# Generating image for seed 18 (18/1000) ...
# Generating image for seed 19 (19/1000) ...
# Generating image for seed 20 (20/1000) ...
# Generating image for seed 21 (21/1000) ...
# Generating image for seed 22 (22/1000) ...
# Generating image for seed 23 (23/1000) ...
# Generating image for seed 24 (24/1000) ...
# Generating image for seed 25 (25/1000) ...
# Generating image for seed 26 (26/1000) ...
# Generating image for seed 27 (27/1000) ...
# Generating image for seed 28 (28/1000) ...
# Generating image for seed 29 (29/1000) ...
# Generating image for seed 30 (30/1000) ...
# Generating image for seed 31 (31/1000) ...
# Generating image for seed 32 (32/1000) ...
# Generating image for seed 33 (33/1000) ...
# Generating image for seed 34 (34/1000) ...
# Generating image for seed 35 (35/1000) ...
# Generating image for seed 36 (36/1000) ...
# Generating image for seed 37 (37/1000) ...
# Generating image for seed 38 (38/1000) ...
# Generating image for seed 39 (39/1000) ...
# Generating image for seed 40 (40/1000) ...
# Generating image for seed 41 (41/1000) ...
# Generating image for seed 42 (42/1000) ...
# Generating image for seed 43 (43/1000) ...
# Generating image for seed 44 (44/1000) ...
# Generating image for seed 45 (45/1000) ...
# Generating image for seed 46 (46/1000) ...
# Generating image for seed 47 (47/1000) ...
# Generating image for seed 48 (48/1000) ...
# Generating image for seed 49 (49/1000) ...
# Generating image for seed 50 (50/1000) ...
# Generating image for seed 51 (51/1000) ...
# Generating image for seed 52 (52/1000) ...
# Generating image for seed 53 (53/1000) ...
# Generating image for seed 54 (54/1000) ...
# Generating image for seed 55 (55/1000) ...
# Generating image for seed 56 (56/1000) ...
# Generating image for seed 57 (57/1000) ...
# Generating image for seed 58 (58/1000) ...
# Generating image for seed 59 (59/1000) ...
# Generating image for seed 60 (60/1000) ...
# Generating image for seed 61 (61/1000) ...
# Generating image for seed 62 (62/1000) ...
# Generating image for seed 63 (63/1000) ...
# Generating image for seed 64 (64/1000) ...
# Generating image for seed 65 (65/1000) ...
# Generating image for seed 66 (66/1000) ...
# Generating image for seed 67 (67/1000) ...
# Generating image for seed 68 (68/1000) ...
# Generating image for seed 69 (69/1000) ...
# Generating image for seed 70 (70/1000) ...
# Generating image for seed 71 (71/1000) ...
# Generating image for seed 72 (72/1000) ...
# Generating image for seed 73 (73/1000) ...
# Generating image for seed 74 (74/1000) ...
# Generating image for seed 75 (75/1000) ...
# Generating image for seed 76 (76/1000) ...
# Generating image for seed 77 (77/1000) ...
# Generating image for seed 78 (78/1000) ...
# Generating image for seed 79 (79/1000) ...
# Generating image for seed 80 (80/1000) ...
# Generating image for seed 81 (81/1000) ...
# Generating image for seed 82 (82/1000) ...
# Generating image for seed 83 (83/1000) ...
# Generating image for seed 84 (84/1000) ...
# Generating image for seed 85 (85/1000) ...
# Generating image for seed 86 (86/1000) ...
# Generating image for seed 87 (87/1000) ...
# Generating image for seed 88 (88/1000) ...
# Generating image for seed 89 (89/1000) ...
# Generating image for seed 90 (90/1000) ...
# Generating image for seed 91 (91/1000) ...
# Generating image for seed 92 (92/1000) ...
# Generating image for seed 93 (93/1000) ...
# Generating image for seed 94 (94/1000) ...
# Generating image for seed 95 (95/1000) ...
# Generating image for seed 96 (96/1000) ...
# Generating image for seed 97 (97/1000) ...
# Generating image for seed 98 (98/1000) ...
# Generating image for seed 99 (99/1000) ...
# Generating image for seed 100 (100/1000) ...
# Generating image for seed 101 (101/1000) ...
# Generating image for seed 102 (102/1000) ...
# Generating image for seed 103 (103/1000) ...
# Generating image for seed 104 (104/1000) ...
# Generating image for seed 105 (105/1000) ...
# Generating image for seed 106 (106/1000) ...
# Generating image for seed 107 (107/1000) ...
# Generating image for seed 108 (108/1000) ...
# Generating image for seed 109 (109/1000) ...
# Generating image for seed 110 (110/1000) ...
# Generating image for seed 111 (111/1000) ...
# Generating image for seed 112 (112/1000) ...
# Generating image for seed 113 (113/1000) ...
# Generating image for seed 114 (114/1000) ...
# Generating image for seed 115 (115/1000) ...
# Generating image for seed 116 (116/1000) ...
# Generating image for seed 117 (117/1000) ...
# Generating image for seed 118 (118/1000) ...
# Generating image for seed 119 (119/1000) ...
# Generating image for seed 120 (120/1000) ...
# Generating image for seed 121 (121/1000) ...
# Generating image for seed 122 (122/1000) ...
# Generating image for seed 123 (123/1000) ...
# Generating image for seed 124 (124/1000) ...
# Generating image for seed 125 (125/1000) ...
# Generating image for seed 126 (126/1000) ...
# Generating image for seed 127 (127/1000) ...
# Generating image for seed 128 (128/1000) ...
# Generating image for seed 129 (129/1000) ...
# Generating image for seed 130 (130/1000) ...
# Generating image for seed 131 (131/1000) ...
# Generating image for seed 132 (132/1000) ...
# Generating image for seed 133 (133/1000) ...
# Generating image for seed 134 (134/1000) ...
# Generating image for seed 135 (135/1000) ...
# Generating image for seed 136 (136/1000) ...
# Generating image for seed 137 (137/1000) ...
# Generating image for seed 138 (138/1000) ...
# Generating image for seed 139 (139/1000) ...
# Generating image for seed 140 (140/1000) ...
# Generating image for seed 141 (141/1000) ...
# Generating image for seed 142 (142/1000) ...
# Generating image for seed 143 (143/1000) ...
# Generating image for seed 144 (144/1000) ...
# Generating image for seed 145 (145/1000) ...
# Generating image for seed 146 (146/1000) ...
# Generating image for seed 147 (147/1000) ...
# Generating image for seed 148 (148/1000) ...
# Generating image for seed 149 (149/1000) ...
# Generating image for seed 150 (150/1000) ...
# Generating image for seed 151 (151/1000) ...
# Generating image for seed 152 (152/1000) ...
# Generating image for seed 153 (153/1000) ...
# Generating image for seed 154 (154/1000) ...
# Generating image for seed 155 (155/1000) ...
# Generating image for seed 156 (156/1000) ...
# Generating image for seed 157 (157/1000) ...
# Generating image for seed 158 (158/1000) ...
# Generating image for seed 159 (159/1000) ...
# Generating image for seed 160 (160/1000) ...
# Generating image for seed 161 (161/1000) ...
# Generating image for seed 162 (162/1000) ...
# Generating image for seed 163 (163/1000) ...
# Generating image for seed 164 (164/1000) ...
# Generating image for seed 165 (165/1000) ...
# Generating image for seed 166 (166/1000) ...
# Generating image for seed 167 (167/1000) ...
# Generating image for seed 168 (168/1000) ...
# Generating image for seed 169 (169/1000) ...
# Generating image for seed 170 (170/1000) ...
# Generating image for seed 171 (171/1000) ...
# Generating image for seed 172 (172/1000) ...
# Generating image for seed 173 (173/1000) ...
# Generating image for seed 174 (174/1000) ...
# Generating image for seed 175 (175/1000) ...
# Generating image for seed 176 (176/1000) ...
# Generating image for seed 177 (177/1000) ...
# Generating image for seed 178 (178/1000) ...
# Generating image for seed 179 (179/1000) ...
# Generating image for seed 180 (180/1000) ...
# Generating image for seed 181 (181/1000) ...
# Generating image for seed 182 (182/1000) ...
# Generating image for seed 183 (183/1000) ...
# Generating image for seed 184 (184/1000) ...
# Generating image for seed 185 (185/1000) ...
# Generating image for seed 186 (186/1000) ...
# Generating image for seed 187 (187/1000) ...
# Generating image for seed 188 (188/1000) ...
# Generating image for seed 189 (189/1000) ...
# Generating image for seed 190 (190/1000) ...
# Generating image for seed 191 (191/1000) ...
# Generating image for seed 192 (192/1000) ...
# Generating image for seed 193 (193/1000) ...
# Generating image for seed 194 (194/1000) ...
# Generating image for seed 195 (195/1000) ...
# Generating image for seed 196 (196/1000) ...
# Generating image for seed 197 (197/1000) ...
# Generating image for seed 198 (198/1000) ...
# Generating image for seed 199 (199/1000) ...
# Generating image for seed 200 (200/1000) ...
# Generating image for seed 201 (201/1000) ...
# Generating image for seed 202 (202/1000) ...
# Generating image for seed 203 (203/1000) ...
# Generating image for seed 204 (204/1000) ...
# Generating image for seed 205 (205/1000) ...
# Generating image for seed 206 (206/1000) ...
# Generating image for seed 207 (207/1000) ...
# Generating image for seed 208 (208/1000) ...
# Generating image for seed 209 (209/1000) ...
# Generating image for seed 210 (210/1000) ...
# Generating image for seed 211 (211/1000) ...
# Generating image for seed 212 (212/1000) ...
# Generating image for seed 213 (213/1000) ...
# Generating image for seed 214 (214/1000) ...
# Generating image for seed 215 (215/1000) ...
# Generating image for seed 216 (216/1000) ...
# Generating image for seed 217 (217/1000) ...
# Generating image for seed 218 (218/1000) ...
# Generating image for seed 219 (219/1000) ...
# Generating image for seed 220 (220/1000) ...
# Generating image for seed 221 (221/1000) ...
# Generating image for seed 222 (222/1000) ...
# Generating image for seed 223 (223/1000) ...
# Generating image for seed 224 (224/1000) ...
# Generating image for seed 225 (225/1000) ...
# Generating image for seed 226 (226/1000) ...
# Generating image for seed 227 (227/1000) ...
# Generating image for seed 228 (228/1000) ...
# Generating image for seed 229 (229/1000) ...
# Generating image for seed 230 (230/1000) ...
# Generating image for seed 231 (231/1000) ...
# Generating image for seed 232 (232/1000) ...
# Generating image for seed 233 (233/1000) ...
# Generating image for seed 234 (234/1000) ...
# Generating image for seed 235 (235/1000) ...
# Generating image for seed 236 (236/1000) ...
# Generating image for seed 237 (237/1000) ...
# Generating image for seed 238 (238/1000) ...
# Generating image for seed 239 (239/1000) ...
# Generating image for seed 240 (240/1000) ...
# Generating image for seed 241 (241/1000) ...
# Generating image for seed 242 (242/1000) ...
# Generating image for seed 243 (243/1000) ...
# Generating image for seed 244 (244/1000) ...
# Generating image for seed 245 (245/1000) ...
# Generating image for seed 246 (246/1000) ...
# Generating image for seed 247 (247/1000) ...
# Generating image for seed 248 (248/1000) ...
# Generating image for seed 249 (249/1000) ...
# Generating image for seed 250 (250/1000) ...
# Generating image for seed 251 (251/1000) ...
# Generating image for seed 252 (252/1000) ...
# Generating image for seed 253 (253/1000) ...
# Generating image for seed 254 (254/1000) ...
# Generating image for seed 255 (255/1000) ...
# Generating image for seed 256 (256/1000) ...
# Generating image for seed 257 (257/1000) ...
# Generating image for seed 258 (258/1000) ...
# Generating image for seed 259 (259/1000) ...
# Generating image for seed 260 (260/1000) ...
# Generating image for seed 261 (261/1000) ...
# Generating image for seed 262 (262/1000) ...
# Generating image for seed 263 (263/1000) ...
# Generating image for seed 264 (264/1000) ...
# Generating image for seed 265 (265/1000) ...
# Generating image for seed 266 (266/1000) ...
# Generating image for seed 267 (267/1000) ...
# Generating image for seed 268 (268/1000) ...
# Generating image for seed 269 (269/1000) ...
# Generating image for seed 270 (270/1000) ...
# Generating image for seed 271 (271/1000) ...
# Generating image for seed 272 (272/1000) ...
# Generating image for seed 273 (273/1000) ...
# Generating image for seed 274 (274/1000) ...
# Generating image for seed 275 (275/1000) ...
# Generating image for seed 276 (276/1000) ...
# Generating image for seed 277 (277/1000) ...
# Generating image for seed 278 (278/1000) ...
# Generating image for seed 279 (279/1000) ...
# Generating image for seed 280 (280/1000) ...
# Generating image for seed 281 (281/1000) ...
# Generating image for seed 282 (282/1000) ...
# Generating image for seed 283 (283/1000) ...
# Generating image for seed 284 (284/1000) ...
# Generating image for seed 285 (285/1000) ...
# Generating image for seed 286 (286/1000) ...
# Generating image for seed 287 (287/1000) ...
# Generating image for seed 288 (288/1000) ...
# Generating image for seed 289 (289/1000) ...
# Generating image for seed 290 (290/1000) ...
# Generating image for seed 291 (291/1000) ...
# Generating image for seed 292 (292/1000) ...
# Generating image for seed 293 (293/1000) ...
# Generating image for seed 294 (294/1000) ...
# Generating image for seed 295 (295/1000) ...
# Generating image for seed 296 (296/1000) ...
# Generating image for seed 297 (297/1000) ...
# Generating image for seed 298 (298/1000) ...
# Generating image for seed 299 (299/1000) ...
# Generating image for seed 300 (300/1000) ...
# Generating image for seed 301 (301/1000) ...
# Generating image for seed 302 (302/1000) ...
# Generating image for seed 303 (303/1000) ...
# Generating image for seed 304 (304/1000) ...
# Generating image for seed 305 (305/1000) ...
# Generating image for seed 306 (306/1000) ...
# Generating image for seed 307 (307/1000) ...
# Generating image for seed 308 (308/1000) ...
# Generating image for seed 309 (309/1000) ...
# Generating image for seed 310 (310/1000) ...
# Generating image for seed 311 (311/1000) ...
# Generating image for seed 312 (312/1000) ...
# Generating image for seed 313 (313/1000) ...
# Generating image for seed 314 (314/1000) ...
# Generating image for seed 315 (315/1000) ...
# Generating image for seed 316 (316/1000) ...
# Generating image for seed 317 (317/1000) ...
# Generating image for seed 318 (318/1000) ...
# Generating image for seed 319 (319/1000) ...
# Generating image for seed 320 (320/1000) ...
# Generating image for seed 321 (321/1000) ...
# Generating image for seed 322 (322/1000) ...
# Generating image for seed 323 (323/1000) ...
# Generating image for seed 324 (324/1000) ...
# Generating image for seed 325 (325/1000) ...
# Generating image for seed 326 (326/1000) ...
# Generating image for seed 327 (327/1000) ...
# Generating image for seed 328 (328/1000) ...
# Generating image for seed 329 (329/1000) ...
# Generating image for seed 330 (330/1000) ...
# Generating image for seed 331 (331/1000) ...
# Generating image for seed 332 (332/1000) ...
# Generating image for seed 333 (333/1000) ...
# Generating image for seed 334 (334/1000) ...
# Generating image for seed 335 (335/1000) ...
# Generating image for seed 336 (336/1000) ...
# Generating image for seed 337 (337/1000) ...
# Generating image for seed 338 (338/1000) ...
# Generating image for seed 339 (339/1000) ...
# Generating image for seed 340 (340/1000) ...
# Generating image for seed 341 (341/1000) ...
# Generating image for seed 342 (342/1000) ...
# Generating image for seed 343 (343/1000) ...
# Generating image for seed 344 (344/1000) ...
# Generating image for seed 345 (345/1000) ...
# Generating image for seed 346 (346/1000) ...
# Generating image for seed 347 (347/1000) ...
# Generating image for seed 348 (348/1000) ...
# Generating image for seed 349 (349/1000) ...
# Generating image for seed 350 (350/1000) ...
# Generating image for seed 351 (351/1000) ...
# Generating image for seed 352 (352/1000) ...
# Generating image for seed 353 (353/1000) ...
# Generating image for seed 354 (354/1000) ...
# Generating image for seed 355 (355/1000) ...
# Generating image for seed 356 (356/1000) ...
# Generating image for seed 357 (357/1000) ...
# Generating image for seed 358 (358/1000) ...
# Generating image for seed 359 (359/1000) ...
# Generating image for seed 360 (360/1000) ...
# Generating image for seed 361 (361/1000) ...
# Generating image for seed 362 (362/1000) ...
# Generating image for seed 363 (363/1000) ...
# Generating image for seed 364 (364/1000) ...
# Generating image for seed 365 (365/1000) ...
# Generating image for seed 366 (366/1000) ...
# Generating image for seed 367 (367/1000) ...
# Generating image for seed 368 (368/1000) ...
# Generating image for seed 369 (369/1000) ...
# Generating image for seed 370 (370/1000) ...
# Generating image for seed 371 (371/1000) ...
# Generating image for seed 372 (372/1000) ...
# Generating image for seed 373 (373/1000) ...
# Generating image for seed 374 (374/1000) ...
# Generating image for seed 375 (375/1000) ...
# Generating image for seed 376 (376/1000) ...
# Generating image for seed 377 (377/1000) ...
# Generating image for seed 378 (378/1000) ...
# Generating image for seed 379 (379/1000) ...
# Generating image for seed 380 (380/1000) ...
# Generating image for seed 381 (381/1000) ...
# Generating image for seed 382 (382/1000) ...
# Generating image for seed 383 (383/1000) ...
# Generating image for seed 384 (384/1000) ...
# Generating image for seed 385 (385/1000) ...
# Generating image for seed 386 (386/1000) ...
# Generating image for seed 387 (387/1000) ...
# Generating image for seed 388 (388/1000) ...
# Generating image for seed 389 (389/1000) ...
# Generating image for seed 390 (390/1000) ...
# Generating image for seed 391 (391/1000) ...
# Generating image for seed 392 (392/1000) ...
# Generating image for seed 393 (393/1000) ...
# Generating image for seed 394 (394/1000) ...
# Generating image for seed 395 (395/1000) ...
# Generating image for seed 396 (396/1000) ...
# Generating image for seed 397 (397/1000) ...
# Generating image for seed 398 (398/1000) ...
# Generating image for seed 399 (399/1000) ...
# Generating image for seed 400 (400/1000) ...
# Generating image for seed 401 (401/1000) ...
# Generating image for seed 402 (402/1000) ...
# Generating image for seed 403 (403/1000) ...
# Generating image for seed 404 (404/1000) ...
# Generating image for seed 405 (405/1000) ...
# Generating image for seed 406 (406/1000) ...
# Generating image for seed 407 (407/1000) ...
# Generating image for seed 408 (408/1000) ...
# Generating image for seed 409 (409/1000) ...
# Generating image for seed 410 (410/1000) ...
# Generating image for seed 411 (411/1000) ...
# Generating image for seed 412 (412/1000) ...
# Generating image for seed 413 (413/1000) ...
# Generating image for seed 414 (414/1000) ...
# Generating image for seed 415 (415/1000) ...
# Generating image for seed 416 (416/1000) ...
# Generating image for seed 417 (417/1000) ...
# Generating image for seed 418 (418/1000) ...
# Generating image for seed 419 (419/1000) ...
# Generating image for seed 420 (420/1000) ...
# Generating image for seed 421 (421/1000) ...
# Generating image for seed 422 (422/1000) ...
# Generating image for seed 423 (423/1000) ...
# Generating image for seed 424 (424/1000) ...
# Generating image for seed 425 (425/1000) ...
# Generating image for seed 426 (426/1000) ...
# Generating image for seed 427 (427/1000) ...
# Generating image for seed 428 (428/1000) ...
# Generating image for seed 429 (429/1000) ...
# Generating image for seed 430 (430/1000) ...
# Generating image for seed 431 (431/1000) ...
# Generating image for seed 432 (432/1000) ...
# Generating image for seed 433 (433/1000) ...
# Generating image for seed 434 (434/1000) ...
# Generating image for seed 435 (435/1000) ...
# Generating image for seed 436 (436/1000) ...
# Generating image for seed 437 (437/1000) ...
# Generating image for seed 438 (438/1000) ...
# Generating image for seed 439 (439/1000) ...
# Generating image for seed 440 (440/1000) ...
# Generating image for seed 441 (441/1000) ...
# Generating image for seed 442 (442/1000) ...
# Generating image for seed 443 (443/1000) ...
# Generating image for seed 444 (444/1000) ...
# Generating image for seed 445 (445/1000) ...
# Generating image for seed 446 (446/1000) ...
# Generating image for seed 447 (447/1000) ...
# Generating image for seed 448 (448/1000) ...
# Generating image for seed 449 (449/1000) ...
# Generating image for seed 450 (450/1000) ...
# Generating image for seed 451 (451/1000) ...
# Generating image for seed 452 (452/1000) ...
# Generating image for seed 453 (453/1000) ...
# Generating image for seed 454 (454/1000) ...
# Generating image for seed 455 (455/1000) ...
# Generating image for seed 456 (456/1000) ...
# Generating image for seed 457 (457/1000) ...
# Generating image for seed 458 (458/1000) ...
# Generating image for seed 459 (459/1000) ...
# Generating image for seed 460 (460/1000) ...
# Generating image for seed 461 (461/1000) ...
# Generating image for seed 462 (462/1000) ...
# Generating image for seed 463 (463/1000) ...
# Generating image for seed 464 (464/1000) ...
# Generating image for seed 465 (465/1000) ...
# Generating image for seed 466 (466/1000) ...
# Generating image for seed 467 (467/1000) ...
# Generating image for seed 468 (468/1000) ...
# Generating image for seed 469 (469/1000) ...
# Generating image for seed 470 (470/1000) ...
# Generating image for seed 471 (471/1000) ...
# Generating image for seed 472 (472/1000) ...
# Generating image for seed 473 (473/1000) ...
# Generating image for seed 474 (474/1000) ...
# Generating image for seed 475 (475/1000) ...
# Generating image for seed 476 (476/1000) ...
# Generating image for seed 477 (477/1000) ...
# Generating image for seed 478 (478/1000) ...
# Generating image for seed 479 (479/1000) ...
# Generating image for seed 480 (480/1000) ...
# Generating image for seed 481 (481/1000) ...
# Generating image for seed 482 (482/1000) ...
# Generating image for seed 483 (483/1000) ...
# Generating image for seed 484 (484/1000) ...
# Generating image for seed 485 (485/1000) ...
# Generating image for seed 486 (486/1000) ...
# Generating image for seed 487 (487/1000) ...
# Generating image for seed 488 (488/1000) ...
# Generating image for seed 489 (489/1000) ...
# Generating image for seed 490 (490/1000) ...
# Generating image for seed 491 (491/1000) ...
# Generating image for seed 492 (492/1000) ...
# Generating image for seed 493 (493/1000) ...
# Generating image for seed 494 (494/1000) ...
# Generating image for seed 495 (495/1000) ...
# Generating image for seed 496 (496/1000) ...
# Generating image for seed 497 (497/1000) ...
# Generating image for seed 498 (498/1000) ...
# Generating image for seed 499 (499/1000) ...
# Generating image for seed 500 (500/1000) ...
# Generating image for seed 501 (501/1000) ...
# Generating image for seed 502 (502/1000) ...
# Generating image for seed 503 (503/1000) ...
# Generating image for seed 504 (504/1000) ...
# Generating image for seed 505 (505/1000) ...
# Generating image for seed 506 (506/1000) ...
# Generating image for seed 507 (507/1000) ...
# Generating image for seed 508 (508/1000) ...
# Generating image for seed 509 (509/1000) ...
# Generating image for seed 510 (510/1000) ...
# Generating image for seed 511 (511/1000) ...
# Generating image for seed 512 (512/1000) ...
# Generating image for seed 513 (513/1000) ...
# Generating image for seed 514 (514/1000) ...
# Generating image for seed 515 (515/1000) ...
# Generating image for seed 516 (516/1000) ...
# Generating image for seed 517 (517/1000) ...
# Generating image for seed 518 (518/1000) ...
# Generating image for seed 519 (519/1000) ...
# Generating image for seed 520 (520/1000) ...
# Generating image for seed 521 (521/1000) ...
# Generating image for seed 522 (522/1000) ...
# Generating image for seed 523 (523/1000) ...
# Generating image for seed 524 (524/1000) ...
# Generating image for seed 525 (525/1000) ...
# Generating image for seed 526 (526/1000) ...
# Generating image for seed 527 (527/1000) ...
# Generating image for seed 528 (528/1000) ...
# Generating image for seed 529 (529/1000) ...
# Generating image for seed 530 (530/1000) ...
# Generating image for seed 531 (531/1000) ...
# Generating image for seed 532 (532/1000) ...
# Generating image for seed 533 (533/1000) ...
# Generating image for seed 534 (534/1000) ...
# Generating image for seed 535 (535/1000) ...
# Generating image for seed 536 (536/1000) ...
# Generating image for seed 537 (537/1000) ...
# Generating image for seed 538 (538/1000) ...
# Generating image for seed 539 (539/1000) ...
# Generating image for seed 540 (540/1000) ...
# Generating image for seed 541 (541/1000) ...
# Generating image for seed 542 (542/1000) ...
# Generating image for seed 543 (543/1000) ...
# Generating image for seed 544 (544/1000) ...
# Generating image for seed 545 (545/1000) ...
# Generating image for seed 546 (546/1000) ...
# Generating image for seed 547 (547/1000) ...
# Generating image for seed 548 (548/1000) ...
# Generating image for seed 549 (549/1000) ...
# Generating image for seed 550 (550/1000) ...
# Generating image for seed 551 (551/1000) ...
# Generating image for seed 552 (552/1000) ...
# Generating image for seed 553 (553/1000) ...
# Generating image for seed 554 (554/1000) ...
# Generating image for seed 555 (555/1000) ...
# Generating image for seed 556 (556/1000) ...
# Generating image for seed 557 (557/1000) ...
# Generating image for seed 558 (558/1000) ...
# Generating image for seed 559 (559/1000) ...
# Generating image for seed 560 (560/1000) ...
# Generating image for seed 561 (561/1000) ...
# Generating image for seed 562 (562/1000) ...
# Generating image for seed 563 (563/1000) ...
# Generating image for seed 564 (564/1000) ...
# Generating image for seed 565 (565/1000) ...
# Generating image for seed 566 (566/1000) ...
# Generating image for seed 567 (567/1000) ...
# Generating image for seed 568 (568/1000) ...
# Generating image for seed 569 (569/1000) ...
# Generating image for seed 570 (570/1000) ...
# Generating image for seed 571 (571/1000) ...
# Generating image for seed 572 (572/1000) ...
# Generating image for seed 573 (573/1000) ...
# Generating image for seed 574 (574/1000) ...
# Generating image for seed 575 (575/1000) ...
# Generating image for seed 576 (576/1000) ...
# Generating image for seed 577 (577/1000) ...
# Generating image for seed 578 (578/1000) ...
# Generating image for seed 579 (579/1000) ...
# Generating image for seed 580 (580/1000) ...
# Generating image for seed 581 (581/1000) ...
# Generating image for seed 582 (582/1000) ...
# Generating image for seed 583 (583/1000) ...
# Generating image for seed 584 (584/1000) ...
# Generating image for seed 585 (585/1000) ...
# Generating image for seed 586 (586/1000) ...
# Generating image for seed 587 (587/1000) ...
# Generating image for seed 588 (588/1000) ...
# Generating image for seed 589 (589/1000) ...
# Generating image for seed 590 (590/1000) ...
# Generating image for seed 591 (591/1000) ...
# Generating image for seed 592 (592/1000) ...
# Generating image for seed 593 (593/1000) ...
# Generating image for seed 594 (594/1000) ...
# Generating image for seed 595 (595/1000) ...
# Generating image for seed 596 (596/1000) ...
# Generating image for seed 597 (597/1000) ...
# Generating image for seed 598 (598/1000) ...
# Generating image for seed 599 (599/1000) ...
# Generating image for seed 600 (600/1000) ...
# Generating image for seed 601 (601/1000) ...
# Generating image for seed 602 (602/1000) ...
# Generating image for seed 603 (603/1000) ...
# Generating image for seed 604 (604/1000) ...
# Generating image for seed 605 (605/1000) ...
# Generating image for seed 606 (606/1000) ...
# Generating image for seed 607 (607/1000) ...
# Generating image for seed 608 (608/1000) ...
# Generating image for seed 609 (609/1000) ...
# Generating image for seed 610 (610/1000) ...
# Generating image for seed 611 (611/1000) ...
# Generating image for seed 612 (612/1000) ...
# Generating image for seed 613 (613/1000) ...
# Generating image for seed 614 (614/1000) ...
# Generating image for seed 615 (615/1000) ...
# Generating image for seed 616 (616/1000) ...
# Generating image for seed 617 (617/1000) ...
# Generating image for seed 618 (618/1000) ...
# Generating image for seed 619 (619/1000) ...
# Generating image for seed 620 (620/1000) ...
# Generating image for seed 621 (621/1000) ...
# Generating image for seed 622 (622/1000) ...
# Generating image for seed 623 (623/1000) ...
# Generating image for seed 624 (624/1000) ...
# Generating image for seed 625 (625/1000) ...
# Generating image for seed 626 (626/1000) ...
# Generating image for seed 627 (627/1000) ...
# Generating image for seed 628 (628/1000) ...
# Generating image for seed 629 (629/1000) ...
# Generating image for seed 630 (630/1000) ...
# Generating image for seed 631 (631/1000) ...
# Generating image for seed 632 (632/1000) ...
# Generating image for seed 633 (633/1000) ...
# Generating image for seed 634 (634/1000) ...
# Generating image for seed 635 (635/1000) ...
# Generating image for seed 636 (636/1000) ...
# Generating image for seed 637 (637/1000) ...
# Generating image for seed 638 (638/1000) ...
# Generating image for seed 639 (639/1000) ...
# Generating image for seed 640 (640/1000) ...
# Generating image for seed 641 (641/1000) ...
# Generating image for seed 642 (642/1000) ...
# Generating image for seed 643 (643/1000) ...
# Generating image for seed 644 (644/1000) ...
# Generating image for seed 645 (645/1000) ...
# Generating image for seed 646 (646/1000) ...
# Generating image for seed 647 (647/1000) ...
# Generating image for seed 648 (648/1000) ...
# Generating image for seed 649 (649/1000) ...
# Generating image for seed 650 (650/1000) ...
# Generating image for seed 651 (651/1000) ...
# Generating image for seed 652 (652/1000) ...
# Generating image for seed 653 (653/1000) ...
# Generating image for seed 654 (654/1000) ...
# Generating image for seed 655 (655/1000) ...
# Generating image for seed 656 (656/1000) ...
# Generating image for seed 657 (657/1000) ...
# Generating image for seed 658 (658/1000) ...
# Generating image for seed 659 (659/1000) ...
# Generating image for seed 660 (660/1000) ...
# Generating image for seed 661 (661/1000) ...
# Generating image for seed 662 (662/1000) ...
# Generating image for seed 663 (663/1000) ...
# Generating image for seed 664 (664/1000) ...
# Generating image for seed 665 (665/1000) ...
# Generating image for seed 666 (666/1000) ...
# Generating image for seed 667 (667/1000) ...
# Generating image for seed 668 (668/1000) ...
# Generating image for seed 669 (669/1000) ...
# Generating image for seed 670 (670/1000) ...
# Generating image for seed 671 (671/1000) ...
# Generating image for seed 672 (672/1000) ...
# Generating image for seed 673 (673/1000) ...
# Generating image for seed 674 (674/1000) ...
# Generating image for seed 675 (675/1000) ...
# Generating image for seed 676 (676/1000) ...
# Generating image for seed 677 (677/1000) ...
# Generating image for seed 678 (678/1000) ...
# Generating image for seed 679 (679/1000) ...
# Generating image for seed 680 (680/1000) ...
# Generating image for seed 681 (681/1000) ...
# Generating image for seed 682 (682/1000) ...
# Generating image for seed 683 (683/1000) ...
# Generating image for seed 684 (684/1000) ...
# Generating image for seed 685 (685/1000) ...
# Generating image for seed 686 (686/1000) ...
# Generating image for seed 687 (687/1000) ...
# Generating image for seed 688 (688/1000) ...
# Generating image for seed 689 (689/1000) ...
# Generating image for seed 690 (690/1000) ...
# Generating image for seed 691 (691/1000) ...
# Generating image for seed 692 (692/1000) ...
# Generating image for seed 693 (693/1000) ...
# Generating image for seed 694 (694/1000) ...
# Generating image for seed 695 (695/1000) ...
# Generating image for seed 696 (696/1000) ...
# Generating image for seed 697 (697/1000) ...
# Generating image for seed 698 (698/1000) ...
# Generating image for seed 699 (699/1000) ...
# Generating image for seed 700 (700/1000) ...
# Generating image for seed 701 (701/1000) ...
# Generating image for seed 702 (702/1000) ...
# Generating image for seed 703 (703/1000) ...
# Generating image for seed 704 (704/1000) ...
# Generating image for seed 705 (705/1000) ...
# Generating image for seed 706 (706/1000) ...
# Generating image for seed 707 (707/1000) ...
# Generating image for seed 708 (708/1000) ...
# Generating image for seed 709 (709/1000) ...
# Generating image for seed 710 (710/1000) ...
# Generating image for seed 711 (711/1000) ...
# Generating image for seed 712 (712/1000) ...
# Generating image for seed 713 (713/1000) ...
# Generating image for seed 714 (714/1000) ...
# Generating image for seed 715 (715/1000) ...
# Generating image for seed 716 (716/1000) ...
# Generating image for seed 717 (717/1000) ...
# Generating image for seed 718 (718/1000) ...
# Generating image for seed 719 (719/1000) ...
# Generating image for seed 720 (720/1000) ...
# Generating image for seed 721 (721/1000) ...
# Generating image for seed 722 (722/1000) ...
# Generating image for seed 723 (723/1000) ...
# Generating image for seed 724 (724/1000) ...
# Generating image for seed 725 (725/1000) ...
# Generating image for seed 726 (726/1000) ...
# Generating image for seed 727 (727/1000) ...
# Generating image for seed 728 (728/1000) ...
# Generating image for seed 729 (729/1000) ...
# Generating image for seed 730 (730/1000) ...
# Generating image for seed 731 (731/1000) ...
# Generating image for seed 732 (732/1000) ...
# Generating image for seed 733 (733/1000) ...
# Generating image for seed 734 (734/1000) ...
# Generating image for seed 735 (735/1000) ...
# Generating image for seed 736 (736/1000) ...
# Generating image for seed 737 (737/1000) ...
# Generating image for seed 738 (738/1000) ...
# Generating image for seed 739 (739/1000) ...
# Generating image for seed 740 (740/1000) ...
# Generating image for seed 741 (741/1000) ...
# Generating image for seed 742 (742/1000) ...
# Generating image for seed 743 (743/1000) ...
# Generating image for seed 744 (744/1000) ...
# Generating image for seed 745 (745/1000) ...
# Generating image for seed 746 (746/1000) ...
# Generating image for seed 747 (747/1000) ...
# Generating image for seed 748 (748/1000) ...
# Generating image for seed 749 (749/1000) ...
# Generating image for seed 750 (750/1000) ...
# Generating image for seed 751 (751/1000) ...
# Generating image for seed 752 (752/1000) ...
# Generating image for seed 753 (753/1000) ...
# Generating image for seed 754 (754/1000) ...
# Generating image for seed 755 (755/1000) ...
# Generating image for seed 756 (756/1000) ...
# Generating image for seed 757 (757/1000) ...
# Generating image for seed 758 (758/1000) ...
# Generating image for seed 759 (759/1000) ...
# Generating image for seed 760 (760/1000) ...
# Generating image for seed 761 (761/1000) ...
# Generating image for seed 762 (762/1000) ...
# Generating image for seed 763 (763/1000) ...
# Generating image for seed 764 (764/1000) ...
# Generating image for seed 765 (765/1000) ...
# Generating image for seed 766 (766/1000) ...
# Generating image for seed 767 (767/1000) ...
# Generating image for seed 768 (768/1000) ...
# Generating image for seed 769 (769/1000) ...
# Generating image for seed 770 (770/1000) ...
# Generating image for seed 771 (771/1000) ...
# Generating image for seed 772 (772/1000) ...
# Generating image for seed 773 (773/1000) ...
# Generating image for seed 774 (774/1000) ...
# Generating image for seed 775 (775/1000) ...
# Generating image for seed 776 (776/1000) ...
# Generating image for seed 777 (777/1000) ...
# Generating image for seed 778 (778/1000) ...
# Generating image for seed 779 (779/1000) ...
# Generating image for seed 780 (780/1000) ...
# Generating image for seed 781 (781/1000) ...
# Generating image for seed 782 (782/1000) ...
# Generating image for seed 783 (783/1000) ...
# Generating image for seed 784 (784/1000) ...
# Generating image for seed 785 (785/1000) ...
# Generating image for seed 786 (786/1000) ...
# Generating image for seed 787 (787/1000) ...
# Generating image for seed 788 (788/1000) ...
# Generating image for seed 789 (789/1000) ...
# Generating image for seed 790 (790/1000) ...
# Generating image for seed 791 (791/1000) ...
# Generating image for seed 792 (792/1000) ...
# Generating image for seed 793 (793/1000) ...
# Generating image for seed 794 (794/1000) ...
# Generating image for seed 795 (795/1000) ...
# Generating image for seed 796 (796/1000) ...
# Generating image for seed 797 (797/1000) ...
# Generating image for seed 798 (798/1000) ...
# Generating image for seed 799 (799/1000) ...
# Generating image for seed 800 (800/1000) ...
# Generating image for seed 801 (801/1000) ...
# Generating image for seed 802 (802/1000) ...
# Generating image for seed 803 (803/1000) ...
# Generating image for seed 804 (804/1000) ...
# Generating image for seed 805 (805/1000) ...
# Generating image for seed 806 (806/1000) ...
# Generating image for seed 807 (807/1000) ...
# Generating image for seed 808 (808/1000) ...
# Generating image for seed 809 (809/1000) ...
# Generating image for seed 810 (810/1000) ...
# Generating image for seed 811 (811/1000) ...
# Generating image for seed 812 (812/1000) ...
# Generating image for seed 813 (813/1000) ...
# Generating image for seed 814 (814/1000) ...
# Generating image for seed 815 (815/1000) ...
# Generating image for seed 816 (816/1000) ...
# Generating image for seed 817 (817/1000) ...
# Generating image for seed 818 (818/1000) ...
# Generating image for seed 819 (819/1000) ...
# Generating image for seed 820 (820/1000) ...
# Generating image for seed 821 (821/1000) ...
# Generating image for seed 822 (822/1000) ...
# Generating image for seed 823 (823/1000) ...
# Generating image for seed 824 (824/1000) ...
# Generating image for seed 825 (825/1000) ...
# Generating image for seed 826 (826/1000) ...
# Generating image for seed 827 (827/1000) ...
# Generating image for seed 828 (828/1000) ...
# Generating image for seed 829 (829/1000) ...
# Generating image for seed 830 (830/1000) ...
# Generating image for seed 831 (831/1000) ...
# Generating image for seed 832 (832/1000) ...
# Generating image for seed 833 (833/1000) ...
# Generating image for seed 834 (834/1000) ...
# Generating image for seed 835 (835/1000) ...
# Generating image for seed 836 (836/1000) ...
# Generating image for seed 837 (837/1000) ...
# Generating image for seed 838 (838/1000) ...
# Generating image for seed 839 (839/1000) ...
# Generating image for seed 840 (840/1000) ...
# Generating image for seed 841 (841/1000) ...
# Generating image for seed 842 (842/1000) ...
# Generating image for seed 843 (843/1000) ...
# Generating image for seed 844 (844/1000) ...
# Generating image for seed 845 (845/1000) ...
# Generating image for seed 846 (846/1000) ...
# Generating image for seed 847 (847/1000) ...
# Generating image for seed 848 (848/1000) ...
# Generating image for seed 849 (849/1000) ...
# Generating image for seed 850 (850/1000) ...
# Generating image for seed 851 (851/1000) ...
# Generating image for seed 852 (852/1000) ...
# Generating image for seed 853 (853/1000) ...
# Generating image for seed 854 (854/1000) ...
# Generating image for seed 855 (855/1000) ...
# Generating image for seed 856 (856/1000) ...
# Generating image for seed 857 (857/1000) ...
# Generating image for seed 858 (858/1000) ...
# Generating image for seed 859 (859/1000) ...
# Generating image for seed 860 (860/1000) ...
# Generating image for seed 861 (861/1000) ...
# Generating image for seed 862 (862/1000) ...
# Generating image for seed 863 (863/1000) ...
# Generating image for seed 864 (864/1000) ...
# Generating image for seed 865 (865/1000) ...
# Generating image for seed 866 (866/1000) ...
# Generating image for seed 867 (867/1000) ...
# Generating image for seed 868 (868/1000) ...
# Generating image for seed 869 (869/1000) ...
# Generating image for seed 870 (870/1000) ...
# Generating image for seed 871 (871/1000) ...
# Generating image for seed 872 (872/1000) ...
# Generating image for seed 873 (873/1000) ...
# Generating image for seed 874 (874/1000) ...
# Generating image for seed 875 (875/1000) ...
# Generating image for seed 876 (876/1000) ...
# Generating image for seed 877 (877/1000) ...
# Generating image for seed 878 (878/1000) ...
# Generating image for seed 879 (879/1000) ...
# Generating image for seed 880 (880/1000) ...
# Generating image for seed 881 (881/1000) ...
# Generating image for seed 882 (882/1000) ...
# Generating image for seed 883 (883/1000) ...
# Generating image for seed 884 (884/1000) ...
# Generating image for seed 885 (885/1000) ...
# Generating image for seed 886 (886/1000) ...
# Generating image for seed 887 (887/1000) ...
# Generating image for seed 888 (888/1000) ...
# Generating image for seed 889 (889/1000) ...
# Generating image for seed 890 (890/1000) ...
# Generating image for seed 891 (891/1000) ...
# Generating image for seed 892 (892/1000) ...
# Generating image for seed 893 (893/1000) ...
# Generating image for seed 894 (894/1000) ...
# Generating image for seed 895 (895/1000) ...
# Generating image for seed 896 (896/1000) ...
# Generating image for seed 897 (897/1000) ...
# Generating image for seed 898 (898/1000) ...
# Generating image for seed 899 (899/1000) ...
# Generating image for seed 900 (900/1000) ...
# Generating image for seed 901 (901/1000) ...
# Generating image for seed 902 (902/1000) ...
# Generating image for seed 903 (903/1000) ...
# Generating image for seed 904 (904/1000) ...
# Generating image for seed 905 (905/1000) ...
# Generating image for seed 906 (906/1000) ...
# Generating image for seed 907 (907/1000) ...
# Generating image for seed 908 (908/1000) ...
# Generating image for seed 909 (909/1000) ...
# Generating image for seed 910 (910/1000) ...
# Generating image for seed 911 (911/1000) ...
# Generating image for seed 912 (912/1000) ...
# Generating image for seed 913 (913/1000) ...
# Generating image for seed 914 (914/1000) ...
# Generating image for seed 915 (915/1000) ...
# Generating image for seed 916 (916/1000) ...
# Generating image for seed 917 (917/1000) ...
# Generating image for seed 918 (918/1000) ...
# Generating image for seed 919 (919/1000) ...
# Generating image for seed 920 (920/1000) ...
# Generating image for seed 921 (921/1000) ...
# Generating image for seed 922 (922/1000) ...
# Generating image for seed 923 (923/1000) ...
# Generating image for seed 924 (924/1000) ...
# Generating image for seed 925 (925/1000) ...
# Generating image for seed 926 (926/1000) ...
# Generating image for seed 927 (927/1000) ...
# Generating image for seed 928 (928/1000) ...
# Generating image for seed 929 (929/1000) ...
# Generating image for seed 930 (930/1000) ...
# Generating image for seed 931 (931/1000) ...
# Generating image for seed 932 (932/1000) ...
# Generating image for seed 933 (933/1000) ...
# Generating image for seed 934 (934/1000) ...
# Generating image for seed 935 (935/1000) ...
# Generating image for seed 936 (936/1000) ...
# Generating image for seed 937 (937/1000) ...
# Generating image for seed 938 (938/1000) ...
# Generating image for seed 939 (939/1000) ...
# Generating image for seed 940 (940/1000) ...
# Generating image for seed 941 (941/1000) ...
# Generating image for seed 942 (942/1000) ...
# Generating image for seed 943 (943/1000) ...
# Generating image for seed 944 (944/1000) ...
# Generating image for seed 945 (945/1000) ...
# Generating image for seed 946 (946/1000) ...
# Generating image for seed 947 (947/1000) ...
# Generating image for seed 948 (948/1000) ...
# Generating image for seed 949 (949/1000) ...
# Generating image for seed 950 (950/1000) ...
# Generating image for seed 951 (951/1000) ...
# Generating image for seed 952 (952/1000) ...
# Generating image for seed 953 (953/1000) ...
# Generating image for seed 954 (954/1000) ...
# Generating image for seed 955 (955/1000) ...
# Generating image for seed 956 (956/1000) ...
# Generating image for seed 957 (957/1000) ...
# Generating image for seed 958 (958/1000) ...
# Generating image for seed 959 (959/1000) ...
# Generating image for seed 960 (960/1000) ...
# Generating image for seed 961 (961/1000) ...
# Generating image for seed 962 (962/1000) ...
# Generating image for seed 963 (963/1000) ...
# Generating image for seed 964 (964/1000) ...
# Generating image for seed 965 (965/1000) ...
# Generating image for seed 966 (966/1000) ...
# Generating image for seed 967 (967/1000) ...
# Generating image for seed 968 (968/1000) ...
# Generating image for seed 969 (969/1000) ...
# Generating image for seed 970 (970/1000) ...
# Generating image for seed 971 (971/1000) ...
# Generating image for seed 972 (972/1000) ...
# Generating image for seed 973 (973/1000) ...
# Generating image for seed 974 (974/1000) ...
# Generating image for seed 975 (975/1000) ...
# Generating image for seed 976 (976/1000) ...
# Generating image for seed 977 (977/1000) ...
# Generating image for seed 978 (978/1000) ...
# Generating image for seed 979 (979/1000) ...
# Generating image for seed 980 (980/1000) ...
# Generating image for seed 981 (981/1000) ...
# Generating image for seed 982 (982/1000) ...
# Generating image for seed 983 (983/1000) ...
# Generating image for seed 984 (984/1000) ...
# Generating image for seed 985 (985/1000) ...
# Generating image for seed 986 (986/1000) ...
# Generating image for seed 987 (987/1000) ...
# Generating image for seed 988 (988/1000) ...
# Generating image for seed 989 (989/1000) ...
# Generating image for seed 990 (990/1000) ...
# Generating image for seed 991 (991/1000) ...
# Generating image for seed 992 (992/1000) ...
# Generating image for seed 993 (993/1000) ...
# Generating image for seed 994 (994/1000) ...
# Generating image for seed 995 (995/1000) ...
# Generating image for seed 996 (996/1000) ...
# Generating image for seed 997 (997/1000) ...
# Generating image for seed 998 (998/1000) ...
# Generating image for seed 999 (999/1000) ...
# dnnlib: Finished run_generator.generate_images() in 1m 17s.

# %% [markdown]
# #### With truncation

# %%
# !python stylegan2/run_generator.py generate-images \
  --seeds=0-999 \
  --truncation-psi=0.5 \
  --network=results/{result_folder_name_to_load}/network-final.pkl \
  --result-dir='/content/drive/My Drive/results' \
# Out:
# Local submit - run_dir: /content/drive/My Drive/results/00057-generate-images
# dnnlib: Running run_generator.generate_images() on localhost...
# Loading networks from "results/00055-stylegan2-steam-1gpu-config-e/network-final.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# Generating image for seed 0 (0/1000) ...
# Generating image for seed 1 (1/1000) ...
# Generating image for seed 2 (2/1000) ...
# Generating image for seed 3 (3/1000) ...
# Generating image for seed 4 (4/1000) ...
# Generating image for seed 5 (5/1000) ...
# Generating image for seed 6 (6/1000) ...
# Generating image for seed 7 (7/1000) ...
# Generating image for seed 8 (8/1000) ...
# Generating image for seed 9 (9/1000) ...
# Generating image for seed 10 (10/1000) ...
# Generating image for seed 11 (11/1000) ...
# Generating image for seed 12 (12/1000) ...
# Generating image for seed 13 (13/1000) ...
# Generating image for seed 14 (14/1000) ...
# Generating image for seed 15 (15/1000) ...
# Generating image for seed 16 (16/1000) ...
# Generating image for seed 17 (17/1000) ...
# Generating image for seed 18 (18/1000) ...
# Generating image for seed 19 (19/1000) ...
# Generating image for seed 20 (20/1000) ...
# Generating image for seed 21 (21/1000) ...
# Generating image for seed 22 (22/1000) ...
# Generating image for seed 23 (23/1000) ...
# Generating image for seed 24 (24/1000) ...
# Generating image for seed 25 (25/1000) ...
# Generating image for seed 26 (26/1000) ...
# Generating image for seed 27 (27/1000) ...
# Generating image for seed 28 (28/1000) ...
# Generating image for seed 29 (29/1000) ...
# Generating image for seed 30 (30/1000) ...
# Generating image for seed 31 (31/1000) ...
# Generating image for seed 32 (32/1000) ...
# Generating image for seed 33 (33/1000) ...
# Generating image for seed 34 (34/1000) ...
# Generating image for seed 35 (35/1000) ...
# Generating image for seed 36 (36/1000) ...
# Generating image for seed 37 (37/1000) ...
# Generating image for seed 38 (38/1000) ...
# Generating image for seed 39 (39/1000) ...
# Generating image for seed 40 (40/1000) ...
# Generating image for seed 41 (41/1000) ...
# Generating image for seed 42 (42/1000) ...
# Generating image for seed 43 (43/1000) ...
# Generating image for seed 44 (44/1000) ...
# Generating image for seed 45 (45/1000) ...
# Generating image for seed 46 (46/1000) ...
# Generating image for seed 47 (47/1000) ...
# Generating image for seed 48 (48/1000) ...
# Generating image for seed 49 (49/1000) ...
# Generating image for seed 50 (50/1000) ...
# Generating image for seed 51 (51/1000) ...
# Generating image for seed 52 (52/1000) ...
# Generating image for seed 53 (53/1000) ...
# Generating image for seed 54 (54/1000) ...
# Generating image for seed 55 (55/1000) ...
# Generating image for seed 56 (56/1000) ...
# Generating image for seed 57 (57/1000) ...
# Generating image for seed 58 (58/1000) ...
# Generating image for seed 59 (59/1000) ...
# Generating image for seed 60 (60/1000) ...
# Generating image for seed 61 (61/1000) ...
# Generating image for seed 62 (62/1000) ...
# Generating image for seed 63 (63/1000) ...
# Generating image for seed 64 (64/1000) ...
# Generating image for seed 65 (65/1000) ...
# Generating image for seed 66 (66/1000) ...
# Generating image for seed 67 (67/1000) ...
# Generating image for seed 68 (68/1000) ...
# Generating image for seed 69 (69/1000) ...
# Generating image for seed 70 (70/1000) ...
# Generating image for seed 71 (71/1000) ...
# Generating image for seed 72 (72/1000) ...
# Generating image for seed 73 (73/1000) ...
# Generating image for seed 74 (74/1000) ...
# Generating image for seed 75 (75/1000) ...
# Generating image for seed 76 (76/1000) ...
# Generating image for seed 77 (77/1000) ...
# Generating image for seed 78 (78/1000) ...
# Generating image for seed 79 (79/1000) ...
# Generating image for seed 80 (80/1000) ...
# Generating image for seed 81 (81/1000) ...
# Generating image for seed 82 (82/1000) ...
# Generating image for seed 83 (83/1000) ...
# Generating image for seed 84 (84/1000) ...
# Generating image for seed 85 (85/1000) ...
# Generating image for seed 86 (86/1000) ...
# Generating image for seed 87 (87/1000) ...
# Generating image for seed 88 (88/1000) ...
# Generating image for seed 89 (89/1000) ...
# Generating image for seed 90 (90/1000) ...
# Generating image for seed 91 (91/1000) ...
# Generating image for seed 92 (92/1000) ...
# Generating image for seed 93 (93/1000) ...
# Generating image for seed 94 (94/1000) ...
# Generating image for seed 95 (95/1000) ...
# Generating image for seed 96 (96/1000) ...
# Generating image for seed 97 (97/1000) ...
# Generating image for seed 98 (98/1000) ...
# Generating image for seed 99 (99/1000) ...
# Generating image for seed 100 (100/1000) ...
# Generating image for seed 101 (101/1000) ...
# Generating image for seed 102 (102/1000) ...
# Generating image for seed 103 (103/1000) ...
# Generating image for seed 104 (104/1000) ...
# Generating image for seed 105 (105/1000) ...
# Generating image for seed 106 (106/1000) ...
# Generating image for seed 107 (107/1000) ...
# Generating image for seed 108 (108/1000) ...
# Generating image for seed 109 (109/1000) ...
# Generating image for seed 110 (110/1000) ...
# Generating image for seed 111 (111/1000) ...
# Generating image for seed 112 (112/1000) ...
# Generating image for seed 113 (113/1000) ...
# Generating image for seed 114 (114/1000) ...
# Generating image for seed 115 (115/1000) ...
# Generating image for seed 116 (116/1000) ...
# Generating image for seed 117 (117/1000) ...
# Generating image for seed 118 (118/1000) ...
# Generating image for seed 119 (119/1000) ...
# Generating image for seed 120 (120/1000) ...
# Generating image for seed 121 (121/1000) ...
# Generating image for seed 122 (122/1000) ...
# Generating image for seed 123 (123/1000) ...
# Generating image for seed 124 (124/1000) ...
# Generating image for seed 125 (125/1000) ...
# Generating image for seed 126 (126/1000) ...
# Generating image for seed 127 (127/1000) ...
# Generating image for seed 128 (128/1000) ...
# Generating image for seed 129 (129/1000) ...
# Generating image for seed 130 (130/1000) ...
# Generating image for seed 131 (131/1000) ...
# Generating image for seed 132 (132/1000) ...
# Generating image for seed 133 (133/1000) ...
# Generating image for seed 134 (134/1000) ...
# Generating image for seed 135 (135/1000) ...
# Generating image for seed 136 (136/1000) ...
# Generating image for seed 137 (137/1000) ...
# Generating image for seed 138 (138/1000) ...
# Generating image for seed 139 (139/1000) ...
# Generating image for seed 140 (140/1000) ...
# Generating image for seed 141 (141/1000) ...
# Generating image for seed 142 (142/1000) ...
# Generating image for seed 143 (143/1000) ...
# Generating image for seed 144 (144/1000) ...
# Generating image for seed 145 (145/1000) ...
# Generating image for seed 146 (146/1000) ...
# Generating image for seed 147 (147/1000) ...
# Generating image for seed 148 (148/1000) ...
# Generating image for seed 149 (149/1000) ...
# Generating image for seed 150 (150/1000) ...
# Generating image for seed 151 (151/1000) ...
# Generating image for seed 152 (152/1000) ...
# Generating image for seed 153 (153/1000) ...
# Generating image for seed 154 (154/1000) ...
# Generating image for seed 155 (155/1000) ...
# Generating image for seed 156 (156/1000) ...
# Generating image for seed 157 (157/1000) ...
# Generating image for seed 158 (158/1000) ...
# Generating image for seed 159 (159/1000) ...
# Generating image for seed 160 (160/1000) ...
# Generating image for seed 161 (161/1000) ...
# Generating image for seed 162 (162/1000) ...
# Generating image for seed 163 (163/1000) ...
# Generating image for seed 164 (164/1000) ...
# Generating image for seed 165 (165/1000) ...
# Generating image for seed 166 (166/1000) ...
# Generating image for seed 167 (167/1000) ...
# Generating image for seed 168 (168/1000) ...
# Generating image for seed 169 (169/1000) ...
# Generating image for seed 170 (170/1000) ...
# Generating image for seed 171 (171/1000) ...
# Generating image for seed 172 (172/1000) ...
# Generating image for seed 173 (173/1000) ...
# Generating image for seed 174 (174/1000) ...
# Generating image for seed 175 (175/1000) ...
# Generating image for seed 176 (176/1000) ...
# Generating image for seed 177 (177/1000) ...
# Generating image for seed 178 (178/1000) ...
# Generating image for seed 179 (179/1000) ...
# Generating image for seed 180 (180/1000) ...
# Generating image for seed 181 (181/1000) ...
# Generating image for seed 182 (182/1000) ...
# Generating image for seed 183 (183/1000) ...
# Generating image for seed 184 (184/1000) ...
# Generating image for seed 185 (185/1000) ...
# Generating image for seed 186 (186/1000) ...
# Generating image for seed 187 (187/1000) ...
# Generating image for seed 188 (188/1000) ...
# Generating image for seed 189 (189/1000) ...
# Generating image for seed 190 (190/1000) ...
# Generating image for seed 191 (191/1000) ...
# Generating image for seed 192 (192/1000) ...
# Generating image for seed 193 (193/1000) ...
# Generating image for seed 194 (194/1000) ...
# Generating image for seed 195 (195/1000) ...
# Generating image for seed 196 (196/1000) ...
# Generating image for seed 197 (197/1000) ...
# Generating image for seed 198 (198/1000) ...
# Generating image for seed 199 (199/1000) ...
# Generating image for seed 200 (200/1000) ...
# Generating image for seed 201 (201/1000) ...
# Generating image for seed 202 (202/1000) ...
# Generating image for seed 203 (203/1000) ...
# Generating image for seed 204 (204/1000) ...
# Generating image for seed 205 (205/1000) ...
# Generating image for seed 206 (206/1000) ...
# Generating image for seed 207 (207/1000) ...
# Generating image for seed 208 (208/1000) ...
# Generating image for seed 209 (209/1000) ...
# Generating image for seed 210 (210/1000) ...
# Generating image for seed 211 (211/1000) ...
# Generating image for seed 212 (212/1000) ...
# Generating image for seed 213 (213/1000) ...
# Generating image for seed 214 (214/1000) ...
# Generating image for seed 215 (215/1000) ...
# Generating image for seed 216 (216/1000) ...
# Generating image for seed 217 (217/1000) ...
# Generating image for seed 218 (218/1000) ...
# Generating image for seed 219 (219/1000) ...
# Generating image for seed 220 (220/1000) ...
# Generating image for seed 221 (221/1000) ...
# Generating image for seed 222 (222/1000) ...
# Generating image for seed 223 (223/1000) ...
# Generating image for seed 224 (224/1000) ...
# Generating image for seed 225 (225/1000) ...
# Generating image for seed 226 (226/1000) ...
# Generating image for seed 227 (227/1000) ...
# Generating image for seed 228 (228/1000) ...
# Generating image for seed 229 (229/1000) ...
# Generating image for seed 230 (230/1000) ...
# Generating image for seed 231 (231/1000) ...
# Generating image for seed 232 (232/1000) ...
# Generating image for seed 233 (233/1000) ...
# Generating image for seed 234 (234/1000) ...
# Generating image for seed 235 (235/1000) ...
# Generating image for seed 236 (236/1000) ...
# Generating image for seed 237 (237/1000) ...
# Generating image for seed 238 (238/1000) ...
# Generating image for seed 239 (239/1000) ...
# Generating image for seed 240 (240/1000) ...
# Generating image for seed 241 (241/1000) ...
# Generating image for seed 242 (242/1000) ...
# Generating image for seed 243 (243/1000) ...
# Generating image for seed 244 (244/1000) ...
# Generating image for seed 245 (245/1000) ...
# Generating image for seed 246 (246/1000) ...
# Generating image for seed 247 (247/1000) ...
# Generating image for seed 248 (248/1000) ...
# Generating image for seed 249 (249/1000) ...
# Generating image for seed 250 (250/1000) ...
# Generating image for seed 251 (251/1000) ...
# Generating image for seed 252 (252/1000) ...
# Generating image for seed 253 (253/1000) ...
# Generating image for seed 254 (254/1000) ...
# Generating image for seed 255 (255/1000) ...
# Generating image for seed 256 (256/1000) ...
# Generating image for seed 257 (257/1000) ...
# Generating image for seed 258 (258/1000) ...
# Generating image for seed 259 (259/1000) ...
# Generating image for seed 260 (260/1000) ...
# Generating image for seed 261 (261/1000) ...
# Generating image for seed 262 (262/1000) ...
# Generating image for seed 263 (263/1000) ...
# Generating image for seed 264 (264/1000) ...
# Generating image for seed 265 (265/1000) ...
# Generating image for seed 266 (266/1000) ...
# Generating image for seed 267 (267/1000) ...
# Generating image for seed 268 (268/1000) ...
# Generating image for seed 269 (269/1000) ...
# Generating image for seed 270 (270/1000) ...
# Generating image for seed 271 (271/1000) ...
# Generating image for seed 272 (272/1000) ...
# Generating image for seed 273 (273/1000) ...
# Generating image for seed 274 (274/1000) ...
# Generating image for seed 275 (275/1000) ...
# Generating image for seed 276 (276/1000) ...
# Generating image for seed 277 (277/1000) ...
# Generating image for seed 278 (278/1000) ...
# Generating image for seed 279 (279/1000) ...
# Generating image for seed 280 (280/1000) ...
# Generating image for seed 281 (281/1000) ...
# Generating image for seed 282 (282/1000) ...
# Generating image for seed 283 (283/1000) ...
# Generating image for seed 284 (284/1000) ...
# Generating image for seed 285 (285/1000) ...
# Generating image for seed 286 (286/1000) ...
# Generating image for seed 287 (287/1000) ...
# Generating image for seed 288 (288/1000) ...
# Generating image for seed 289 (289/1000) ...
# Generating image for seed 290 (290/1000) ...
# Generating image for seed 291 (291/1000) ...
# Generating image for seed 292 (292/1000) ...
# Generating image for seed 293 (293/1000) ...
# Generating image for seed 294 (294/1000) ...
# Generating image for seed 295 (295/1000) ...
# Generating image for seed 296 (296/1000) ...
# Generating image for seed 297 (297/1000) ...
# Generating image for seed 298 (298/1000) ...
# Generating image for seed 299 (299/1000) ...
# Generating image for seed 300 (300/1000) ...
# Generating image for seed 301 (301/1000) ...
# Generating image for seed 302 (302/1000) ...
# Generating image for seed 303 (303/1000) ...
# Generating image for seed 304 (304/1000) ...
# Generating image for seed 305 (305/1000) ...
# Generating image for seed 306 (306/1000) ...
# Generating image for seed 307 (307/1000) ...
# Generating image for seed 308 (308/1000) ...
# Generating image for seed 309 (309/1000) ...
# Generating image for seed 310 (310/1000) ...
# Generating image for seed 311 (311/1000) ...
# Generating image for seed 312 (312/1000) ...
# Generating image for seed 313 (313/1000) ...
# Generating image for seed 314 (314/1000) ...
# Generating image for seed 315 (315/1000) ...
# Generating image for seed 316 (316/1000) ...
# Generating image for seed 317 (317/1000) ...
# Generating image for seed 318 (318/1000) ...
# Generating image for seed 319 (319/1000) ...
# Generating image for seed 320 (320/1000) ...
# Generating image for seed 321 (321/1000) ...
# Generating image for seed 322 (322/1000) ...
# Generating image for seed 323 (323/1000) ...
# Generating image for seed 324 (324/1000) ...
# Generating image for seed 325 (325/1000) ...
# Generating image for seed 326 (326/1000) ...
# Generating image for seed 327 (327/1000) ...
# Generating image for seed 328 (328/1000) ...
# Generating image for seed 329 (329/1000) ...
# Generating image for seed 330 (330/1000) ...
# Generating image for seed 331 (331/1000) ...
# Generating image for seed 332 (332/1000) ...
# Generating image for seed 333 (333/1000) ...
# Generating image for seed 334 (334/1000) ...
# Generating image for seed 335 (335/1000) ...
# Generating image for seed 336 (336/1000) ...
# Generating image for seed 337 (337/1000) ...
# Generating image for seed 338 (338/1000) ...
# Generating image for seed 339 (339/1000) ...
# Generating image for seed 340 (340/1000) ...
# Generating image for seed 341 (341/1000) ...
# Generating image for seed 342 (342/1000) ...
# Generating image for seed 343 (343/1000) ...
# Generating image for seed 344 (344/1000) ...
# Generating image for seed 345 (345/1000) ...
# Generating image for seed 346 (346/1000) ...
# Generating image for seed 347 (347/1000) ...
# Generating image for seed 348 (348/1000) ...
# Generating image for seed 349 (349/1000) ...
# Generating image for seed 350 (350/1000) ...
# Generating image for seed 351 (351/1000) ...
# Generating image for seed 352 (352/1000) ...
# Generating image for seed 353 (353/1000) ...
# Generating image for seed 354 (354/1000) ...
# Generating image for seed 355 (355/1000) ...
# Generating image for seed 356 (356/1000) ...
# Generating image for seed 357 (357/1000) ...
# Generating image for seed 358 (358/1000) ...
# Generating image for seed 359 (359/1000) ...
# Generating image for seed 360 (360/1000) ...
# Generating image for seed 361 (361/1000) ...
# Generating image for seed 362 (362/1000) ...
# Generating image for seed 363 (363/1000) ...
# Generating image for seed 364 (364/1000) ...
# Generating image for seed 365 (365/1000) ...
# Generating image for seed 366 (366/1000) ...
# Generating image for seed 367 (367/1000) ...
# Generating image for seed 368 (368/1000) ...
# Generating image for seed 369 (369/1000) ...
# Generating image for seed 370 (370/1000) ...
# Generating image for seed 371 (371/1000) ...
# Generating image for seed 372 (372/1000) ...
# Generating image for seed 373 (373/1000) ...
# Generating image for seed 374 (374/1000) ...
# Generating image for seed 375 (375/1000) ...
# Generating image for seed 376 (376/1000) ...
# Generating image for seed 377 (377/1000) ...
# Generating image for seed 378 (378/1000) ...
# Generating image for seed 379 (379/1000) ...
# Generating image for seed 380 (380/1000) ...
# Generating image for seed 381 (381/1000) ...
# Generating image for seed 382 (382/1000) ...
# Generating image for seed 383 (383/1000) ...
# Generating image for seed 384 (384/1000) ...
# Generating image for seed 385 (385/1000) ...
# Generating image for seed 386 (386/1000) ...
# Generating image for seed 387 (387/1000) ...
# Generating image for seed 388 (388/1000) ...
# Generating image for seed 389 (389/1000) ...
# Generating image for seed 390 (390/1000) ...
# Generating image for seed 391 (391/1000) ...
# Generating image for seed 392 (392/1000) ...
# Generating image for seed 393 (393/1000) ...
# Generating image for seed 394 (394/1000) ...
# Generating image for seed 395 (395/1000) ...
# Generating image for seed 396 (396/1000) ...
# Generating image for seed 397 (397/1000) ...
# Generating image for seed 398 (398/1000) ...
# Generating image for seed 399 (399/1000) ...
# Generating image for seed 400 (400/1000) ...
# Generating image for seed 401 (401/1000) ...
# Generating image for seed 402 (402/1000) ...
# Generating image for seed 403 (403/1000) ...
# Generating image for seed 404 (404/1000) ...
# Generating image for seed 405 (405/1000) ...
# Generating image for seed 406 (406/1000) ...
# Generating image for seed 407 (407/1000) ...
# Generating image for seed 408 (408/1000) ...
# Generating image for seed 409 (409/1000) ...
# Generating image for seed 410 (410/1000) ...
# Generating image for seed 411 (411/1000) ...
# Generating image for seed 412 (412/1000) ...
# Generating image for seed 413 (413/1000) ...
# Generating image for seed 414 (414/1000) ...
# Generating image for seed 415 (415/1000) ...
# Generating image for seed 416 (416/1000) ...
# Generating image for seed 417 (417/1000) ...
# Generating image for seed 418 (418/1000) ...
# Generating image for seed 419 (419/1000) ...
# Generating image for seed 420 (420/1000) ...
# Generating image for seed 421 (421/1000) ...
# Generating image for seed 422 (422/1000) ...
# Generating image for seed 423 (423/1000) ...
# Generating image for seed 424 (424/1000) ...
# Generating image for seed 425 (425/1000) ...
# Generating image for seed 426 (426/1000) ...
# Generating image for seed 427 (427/1000) ...
# Generating image for seed 428 (428/1000) ...
# Generating image for seed 429 (429/1000) ...
# Generating image for seed 430 (430/1000) ...
# Generating image for seed 431 (431/1000) ...
# Generating image for seed 432 (432/1000) ...
# Generating image for seed 433 (433/1000) ...
# Generating image for seed 434 (434/1000) ...
# Generating image for seed 435 (435/1000) ...
# Generating image for seed 436 (436/1000) ...
# Generating image for seed 437 (437/1000) ...
# Generating image for seed 438 (438/1000) ...
# Generating image for seed 439 (439/1000) ...
# Generating image for seed 440 (440/1000) ...
# Generating image for seed 441 (441/1000) ...
# Generating image for seed 442 (442/1000) ...
# Generating image for seed 443 (443/1000) ...
# Generating image for seed 444 (444/1000) ...
# Generating image for seed 445 (445/1000) ...
# Generating image for seed 446 (446/1000) ...
# Generating image for seed 447 (447/1000) ...
# Generating image for seed 448 (448/1000) ...
# Generating image for seed 449 (449/1000) ...
# Generating image for seed 450 (450/1000) ...
# Generating image for seed 451 (451/1000) ...
# Generating image for seed 452 (452/1000) ...
# Generating image for seed 453 (453/1000) ...
# Generating image for seed 454 (454/1000) ...
# Generating image for seed 455 (455/1000) ...
# Generating image for seed 456 (456/1000) ...
# Generating image for seed 457 (457/1000) ...
# Generating image for seed 458 (458/1000) ...
# Generating image for seed 459 (459/1000) ...
# Generating image for seed 460 (460/1000) ...
# Generating image for seed 461 (461/1000) ...
# Generating image for seed 462 (462/1000) ...
# Generating image for seed 463 (463/1000) ...
# Generating image for seed 464 (464/1000) ...
# Generating image for seed 465 (465/1000) ...
# Generating image for seed 466 (466/1000) ...
# Generating image for seed 467 (467/1000) ...
# Generating image for seed 468 (468/1000) ...
# Generating image for seed 469 (469/1000) ...
# Generating image for seed 470 (470/1000) ...
# Generating image for seed 471 (471/1000) ...
# Generating image for seed 472 (472/1000) ...
# Generating image for seed 473 (473/1000) ...
# Generating image for seed 474 (474/1000) ...
# Generating image for seed 475 (475/1000) ...
# Generating image for seed 476 (476/1000) ...
# Generating image for seed 477 (477/1000) ...
# Generating image for seed 478 (478/1000) ...
# Generating image for seed 479 (479/1000) ...
# Generating image for seed 480 (480/1000) ...
# Generating image for seed 481 (481/1000) ...
# Generating image for seed 482 (482/1000) ...
# Generating image for seed 483 (483/1000) ...
# Generating image for seed 484 (484/1000) ...
# Generating image for seed 485 (485/1000) ...
# Generating image for seed 486 (486/1000) ...
# Generating image for seed 487 (487/1000) ...
# Generating image for seed 488 (488/1000) ...
# Generating image for seed 489 (489/1000) ...
# Generating image for seed 490 (490/1000) ...
# Generating image for seed 491 (491/1000) ...
# Generating image for seed 492 (492/1000) ...
# Generating image for seed 493 (493/1000) ...
# Generating image for seed 494 (494/1000) ...
# Generating image for seed 495 (495/1000) ...
# Generating image for seed 496 (496/1000) ...
# Generating image for seed 497 (497/1000) ...
# Generating image for seed 498 (498/1000) ...
# Generating image for seed 499 (499/1000) ...
# Generating image for seed 500 (500/1000) ...
# Generating image for seed 501 (501/1000) ...
# Generating image for seed 502 (502/1000) ...
# Generating image for seed 503 (503/1000) ...
# Generating image for seed 504 (504/1000) ...
# Generating image for seed 505 (505/1000) ...
# Generating image for seed 506 (506/1000) ...
# Generating image for seed 507 (507/1000) ...
# Generating image for seed 508 (508/1000) ...
# Generating image for seed 509 (509/1000) ...
# Generating image for seed 510 (510/1000) ...
# Generating image for seed 511 (511/1000) ...
# Generating image for seed 512 (512/1000) ...
# Generating image for seed 513 (513/1000) ...
# Generating image for seed 514 (514/1000) ...
# Generating image for seed 515 (515/1000) ...
# Generating image for seed 516 (516/1000) ...
# Generating image for seed 517 (517/1000) ...
# Generating image for seed 518 (518/1000) ...
# Generating image for seed 519 (519/1000) ...
# Generating image for seed 520 (520/1000) ...
# Generating image for seed 521 (521/1000) ...
# Generating image for seed 522 (522/1000) ...
# Generating image for seed 523 (523/1000) ...
# Generating image for seed 524 (524/1000) ...
# Generating image for seed 525 (525/1000) ...
# Generating image for seed 526 (526/1000) ...
# Generating image for seed 527 (527/1000) ...
# Generating image for seed 528 (528/1000) ...
# Generating image for seed 529 (529/1000) ...
# Generating image for seed 530 (530/1000) ...
# Generating image for seed 531 (531/1000) ...
# Generating image for seed 532 (532/1000) ...
# Generating image for seed 533 (533/1000) ...
# Generating image for seed 534 (534/1000) ...
# Generating image for seed 535 (535/1000) ...
# Generating image for seed 536 (536/1000) ...
# Generating image for seed 537 (537/1000) ...
# Generating image for seed 538 (538/1000) ...
# Generating image for seed 539 (539/1000) ...
# Generating image for seed 540 (540/1000) ...
# Generating image for seed 541 (541/1000) ...
# Generating image for seed 542 (542/1000) ...
# Generating image for seed 543 (543/1000) ...
# Generating image for seed 544 (544/1000) ...
# Generating image for seed 545 (545/1000) ...
# Generating image for seed 546 (546/1000) ...
# Generating image for seed 547 (547/1000) ...
# Generating image for seed 548 (548/1000) ...
# Generating image for seed 549 (549/1000) ...
# Generating image for seed 550 (550/1000) ...
# Generating image for seed 551 (551/1000) ...
# Generating image for seed 552 (552/1000) ...
# Generating image for seed 553 (553/1000) ...
# Generating image for seed 554 (554/1000) ...
# Generating image for seed 555 (555/1000) ...
# Generating image for seed 556 (556/1000) ...
# Generating image for seed 557 (557/1000) ...
# Generating image for seed 558 (558/1000) ...
# Generating image for seed 559 (559/1000) ...
# Generating image for seed 560 (560/1000) ...
# Generating image for seed 561 (561/1000) ...
# Generating image for seed 562 (562/1000) ...
# Generating image for seed 563 (563/1000) ...
# Generating image for seed 564 (564/1000) ...
# Generating image for seed 565 (565/1000) ...
# Generating image for seed 566 (566/1000) ...
# Generating image for seed 567 (567/1000) ...
# Generating image for seed 568 (568/1000) ...
# Generating image for seed 569 (569/1000) ...
# Generating image for seed 570 (570/1000) ...
# Generating image for seed 571 (571/1000) ...
# Generating image for seed 572 (572/1000) ...
# Generating image for seed 573 (573/1000) ...
# Generating image for seed 574 (574/1000) ...
# Generating image for seed 575 (575/1000) ...
# Generating image for seed 576 (576/1000) ...
# Generating image for seed 577 (577/1000) ...
# Generating image for seed 578 (578/1000) ...
# Generating image for seed 579 (579/1000) ...
# Generating image for seed 580 (580/1000) ...
# Generating image for seed 581 (581/1000) ...
# Generating image for seed 582 (582/1000) ...
# Generating image for seed 583 (583/1000) ...
# Generating image for seed 584 (584/1000) ...
# Generating image for seed 585 (585/1000) ...
# Generating image for seed 586 (586/1000) ...
# Generating image for seed 587 (587/1000) ...
# Generating image for seed 588 (588/1000) ...
# Generating image for seed 589 (589/1000) ...
# Generating image for seed 590 (590/1000) ...
# Generating image for seed 591 (591/1000) ...
# Generating image for seed 592 (592/1000) ...
# Generating image for seed 593 (593/1000) ...
# Generating image for seed 594 (594/1000) ...
# Generating image for seed 595 (595/1000) ...
# Generating image for seed 596 (596/1000) ...
# Generating image for seed 597 (597/1000) ...
# Generating image for seed 598 (598/1000) ...
# Generating image for seed 599 (599/1000) ...
# Generating image for seed 600 (600/1000) ...
# Generating image for seed 601 (601/1000) ...
# Generating image for seed 602 (602/1000) ...
# Generating image for seed 603 (603/1000) ...
# Generating image for seed 604 (604/1000) ...
# Generating image for seed 605 (605/1000) ...
# Generating image for seed 606 (606/1000) ...
# Generating image for seed 607 (607/1000) ...
# Generating image for seed 608 (608/1000) ...
# Generating image for seed 609 (609/1000) ...
# Generating image for seed 610 (610/1000) ...
# Generating image for seed 611 (611/1000) ...
# Generating image for seed 612 (612/1000) ...
# Generating image for seed 613 (613/1000) ...
# Generating image for seed 614 (614/1000) ...
# Generating image for seed 615 (615/1000) ...
# Generating image for seed 616 (616/1000) ...
# Generating image for seed 617 (617/1000) ...
# Generating image for seed 618 (618/1000) ...
# Generating image for seed 619 (619/1000) ...
# Generating image for seed 620 (620/1000) ...
# Generating image for seed 621 (621/1000) ...
# Generating image for seed 622 (622/1000) ...
# Generating image for seed 623 (623/1000) ...
# Generating image for seed 624 (624/1000) ...
# Generating image for seed 625 (625/1000) ...
# Generating image for seed 626 (626/1000) ...
# Generating image for seed 627 (627/1000) ...
# Generating image for seed 628 (628/1000) ...
# Generating image for seed 629 (629/1000) ...
# Generating image for seed 630 (630/1000) ...
# Generating image for seed 631 (631/1000) ...
# Generating image for seed 632 (632/1000) ...
# Generating image for seed 633 (633/1000) ...
# Generating image for seed 634 (634/1000) ...
# Generating image for seed 635 (635/1000) ...
# Generating image for seed 636 (636/1000) ...
# Generating image for seed 637 (637/1000) ...
# Generating image for seed 638 (638/1000) ...
# Generating image for seed 639 (639/1000) ...
# Generating image for seed 640 (640/1000) ...
# Generating image for seed 641 (641/1000) ...
# Generating image for seed 642 (642/1000) ...
# Generating image for seed 643 (643/1000) ...
# Generating image for seed 644 (644/1000) ...
# Generating image for seed 645 (645/1000) ...
# Generating image for seed 646 (646/1000) ...
# Generating image for seed 647 (647/1000) ...
# Generating image for seed 648 (648/1000) ...
# Generating image for seed 649 (649/1000) ...
# Generating image for seed 650 (650/1000) ...
# Generating image for seed 651 (651/1000) ...
# Generating image for seed 652 (652/1000) ...
# Generating image for seed 653 (653/1000) ...
# Generating image for seed 654 (654/1000) ...
# Generating image for seed 655 (655/1000) ...
# Generating image for seed 656 (656/1000) ...
# Generating image for seed 657 (657/1000) ...
# Generating image for seed 658 (658/1000) ...
# Generating image for seed 659 (659/1000) ...
# Generating image for seed 660 (660/1000) ...
# Generating image for seed 661 (661/1000) ...
# Generating image for seed 662 (662/1000) ...
# Generating image for seed 663 (663/1000) ...
# Generating image for seed 664 (664/1000) ...
# Generating image for seed 665 (665/1000) ...
# Generating image for seed 666 (666/1000) ...
# Generating image for seed 667 (667/1000) ...
# Generating image for seed 668 (668/1000) ...
# Generating image for seed 669 (669/1000) ...
# Generating image for seed 670 (670/1000) ...
# Generating image for seed 671 (671/1000) ...
# Generating image for seed 672 (672/1000) ...
# Generating image for seed 673 (673/1000) ...
# Generating image for seed 674 (674/1000) ...
# Generating image for seed 675 (675/1000) ...
# Generating image for seed 676 (676/1000) ...
# Generating image for seed 677 (677/1000) ...
# Generating image for seed 678 (678/1000) ...
# Generating image for seed 679 (679/1000) ...
# Generating image for seed 680 (680/1000) ...
# Generating image for seed 681 (681/1000) ...
# Generating image for seed 682 (682/1000) ...
# Generating image for seed 683 (683/1000) ...
# Generating image for seed 684 (684/1000) ...
# Generating image for seed 685 (685/1000) ...
# Generating image for seed 686 (686/1000) ...
# Generating image for seed 687 (687/1000) ...
# Generating image for seed 688 (688/1000) ...
# Generating image for seed 689 (689/1000) ...
# Generating image for seed 690 (690/1000) ...
# Generating image for seed 691 (691/1000) ...
# Generating image for seed 692 (692/1000) ...
# Generating image for seed 693 (693/1000) ...
# Generating image for seed 694 (694/1000) ...
# Generating image for seed 695 (695/1000) ...
# Generating image for seed 696 (696/1000) ...
# Generating image for seed 697 (697/1000) ...
# Generating image for seed 698 (698/1000) ...
# Generating image for seed 699 (699/1000) ...
# Generating image for seed 700 (700/1000) ...
# Generating image for seed 701 (701/1000) ...
# Generating image for seed 702 (702/1000) ...
# Generating image for seed 703 (703/1000) ...
# Generating image for seed 704 (704/1000) ...
# Generating image for seed 705 (705/1000) ...
# Generating image for seed 706 (706/1000) ...
# Generating image for seed 707 (707/1000) ...
# Generating image for seed 708 (708/1000) ...
# Generating image for seed 709 (709/1000) ...
# Generating image for seed 710 (710/1000) ...
# Generating image for seed 711 (711/1000) ...
# Generating image for seed 712 (712/1000) ...
# Generating image for seed 713 (713/1000) ...
# Generating image for seed 714 (714/1000) ...
# Generating image for seed 715 (715/1000) ...
# Generating image for seed 716 (716/1000) ...
# Generating image for seed 717 (717/1000) ...
# Generating image for seed 718 (718/1000) ...
# Generating image for seed 719 (719/1000) ...
# Generating image for seed 720 (720/1000) ...
# Generating image for seed 721 (721/1000) ...
# Generating image for seed 722 (722/1000) ...
# Generating image for seed 723 (723/1000) ...
# Generating image for seed 724 (724/1000) ...
# Generating image for seed 725 (725/1000) ...
# Generating image for seed 726 (726/1000) ...
# Generating image for seed 727 (727/1000) ...
# Generating image for seed 728 (728/1000) ...
# Generating image for seed 729 (729/1000) ...
# Generating image for seed 730 (730/1000) ...
# Generating image for seed 731 (731/1000) ...
# Generating image for seed 732 (732/1000) ...
# Generating image for seed 733 (733/1000) ...
# Generating image for seed 734 (734/1000) ...
# Generating image for seed 735 (735/1000) ...
# Generating image for seed 736 (736/1000) ...
# Generating image for seed 737 (737/1000) ...
# Generating image for seed 738 (738/1000) ...
# Generating image for seed 739 (739/1000) ...
# Generating image for seed 740 (740/1000) ...
# Generating image for seed 741 (741/1000) ...
# Generating image for seed 742 (742/1000) ...
# Generating image for seed 743 (743/1000) ...
# Generating image for seed 744 (744/1000) ...
# Generating image for seed 745 (745/1000) ...
# Generating image for seed 746 (746/1000) ...
# Generating image for seed 747 (747/1000) ...
# Generating image for seed 748 (748/1000) ...
# Generating image for seed 749 (749/1000) ...
# Generating image for seed 750 (750/1000) ...
# Generating image for seed 751 (751/1000) ...
# Generating image for seed 752 (752/1000) ...
# Generating image for seed 753 (753/1000) ...
# Generating image for seed 754 (754/1000) ...
# Generating image for seed 755 (755/1000) ...
# Generating image for seed 756 (756/1000) ...
# Generating image for seed 757 (757/1000) ...
# Generating image for seed 758 (758/1000) ...
# Generating image for seed 759 (759/1000) ...
# Generating image for seed 760 (760/1000) ...
# Generating image for seed 761 (761/1000) ...
# Generating image for seed 762 (762/1000) ...
# Generating image for seed 763 (763/1000) ...
# Generating image for seed 764 (764/1000) ...
# Generating image for seed 765 (765/1000) ...
# Generating image for seed 766 (766/1000) ...
# Generating image for seed 767 (767/1000) ...
# Generating image for seed 768 (768/1000) ...
# Generating image for seed 769 (769/1000) ...
# Generating image for seed 770 (770/1000) ...
# Generating image for seed 771 (771/1000) ...
# Generating image for seed 772 (772/1000) ...
# Generating image for seed 773 (773/1000) ...
# Generating image for seed 774 (774/1000) ...
# Generating image for seed 775 (775/1000) ...
# Generating image for seed 776 (776/1000) ...
# Generating image for seed 777 (777/1000) ...
# Generating image for seed 778 (778/1000) ...
# Generating image for seed 779 (779/1000) ...
# Generating image for seed 780 (780/1000) ...
# Generating image for seed 781 (781/1000) ...
# Generating image for seed 782 (782/1000) ...
# Generating image for seed 783 (783/1000) ...
# Generating image for seed 784 (784/1000) ...
# Generating image for seed 785 (785/1000) ...
# Generating image for seed 786 (786/1000) ...
# Generating image for seed 787 (787/1000) ...
# Generating image for seed 788 (788/1000) ...
# Generating image for seed 789 (789/1000) ...
# Generating image for seed 790 (790/1000) ...
# Generating image for seed 791 (791/1000) ...
# Generating image for seed 792 (792/1000) ...
# Generating image for seed 793 (793/1000) ...
# Generating image for seed 794 (794/1000) ...
# Generating image for seed 795 (795/1000) ...
# Generating image for seed 796 (796/1000) ...
# Generating image for seed 797 (797/1000) ...
# Generating image for seed 798 (798/1000) ...
# Generating image for seed 799 (799/1000) ...
# Generating image for seed 800 (800/1000) ...
# Generating image for seed 801 (801/1000) ...
# Generating image for seed 802 (802/1000) ...
# Generating image for seed 803 (803/1000) ...
# Generating image for seed 804 (804/1000) ...
# Generating image for seed 805 (805/1000) ...
# Generating image for seed 806 (806/1000) ...
# Generating image for seed 807 (807/1000) ...
# Generating image for seed 808 (808/1000) ...
# Generating image for seed 809 (809/1000) ...
# Generating image for seed 810 (810/1000) ...
# Generating image for seed 811 (811/1000) ...
# Generating image for seed 812 (812/1000) ...
# Generating image for seed 813 (813/1000) ...
# Generating image for seed 814 (814/1000) ...
# Generating image for seed 815 (815/1000) ...
# Generating image for seed 816 (816/1000) ...
# Generating image for seed 817 (817/1000) ...
# Generating image for seed 818 (818/1000) ...
# Generating image for seed 819 (819/1000) ...
# Generating image for seed 820 (820/1000) ...
# Generating image for seed 821 (821/1000) ...
# Generating image for seed 822 (822/1000) ...
# Generating image for seed 823 (823/1000) ...
# Generating image for seed 824 (824/1000) ...
# Generating image for seed 825 (825/1000) ...
# Generating image for seed 826 (826/1000) ...
# Generating image for seed 827 (827/1000) ...
# Generating image for seed 828 (828/1000) ...
# Generating image for seed 829 (829/1000) ...
# Generating image for seed 830 (830/1000) ...
# Generating image for seed 831 (831/1000) ...
# Generating image for seed 832 (832/1000) ...
# Generating image for seed 833 (833/1000) ...
# Generating image for seed 834 (834/1000) ...
# Generating image for seed 835 (835/1000) ...
# Generating image for seed 836 (836/1000) ...
# Generating image for seed 837 (837/1000) ...
# Generating image for seed 838 (838/1000) ...
# Generating image for seed 839 (839/1000) ...
# Generating image for seed 840 (840/1000) ...
# Generating image for seed 841 (841/1000) ...
# Generating image for seed 842 (842/1000) ...
# Generating image for seed 843 (843/1000) ...
# Generating image for seed 844 (844/1000) ...
# Generating image for seed 845 (845/1000) ...
# Generating image for seed 846 (846/1000) ...
# Generating image for seed 847 (847/1000) ...
# Generating image for seed 848 (848/1000) ...
# Generating image for seed 849 (849/1000) ...
# Generating image for seed 850 (850/1000) ...
# Generating image for seed 851 (851/1000) ...
# Generating image for seed 852 (852/1000) ...
# Generating image for seed 853 (853/1000) ...
# Generating image for seed 854 (854/1000) ...
# Generating image for seed 855 (855/1000) ...
# Generating image for seed 856 (856/1000) ...
# Generating image for seed 857 (857/1000) ...
# Generating image for seed 858 (858/1000) ...
# Generating image for seed 859 (859/1000) ...
# Generating image for seed 860 (860/1000) ...
# Generating image for seed 861 (861/1000) ...
# Generating image for seed 862 (862/1000) ...
# Generating image for seed 863 (863/1000) ...
# Generating image for seed 864 (864/1000) ...
# Generating image for seed 865 (865/1000) ...
# Generating image for seed 866 (866/1000) ...
# Generating image for seed 867 (867/1000) ...
# Generating image for seed 868 (868/1000) ...
# Generating image for seed 869 (869/1000) ...
# Generating image for seed 870 (870/1000) ...
# Generating image for seed 871 (871/1000) ...
# Generating image for seed 872 (872/1000) ...
# Generating image for seed 873 (873/1000) ...
# Generating image for seed 874 (874/1000) ...
# Generating image for seed 875 (875/1000) ...
# Generating image for seed 876 (876/1000) ...
# Generating image for seed 877 (877/1000) ...
# Generating image for seed 878 (878/1000) ...
# Generating image for seed 879 (879/1000) ...
# Generating image for seed 880 (880/1000) ...
# Generating image for seed 881 (881/1000) ...
# Generating image for seed 882 (882/1000) ...
# Generating image for seed 883 (883/1000) ...
# Generating image for seed 884 (884/1000) ...
# Generating image for seed 885 (885/1000) ...
# Generating image for seed 886 (886/1000) ...
# Generating image for seed 887 (887/1000) ...
# Generating image for seed 888 (888/1000) ...
# Generating image for seed 889 (889/1000) ...
# Generating image for seed 890 (890/1000) ...
# Generating image for seed 891 (891/1000) ...
# Generating image for seed 892 (892/1000) ...
# Generating image for seed 893 (893/1000) ...
# Generating image for seed 894 (894/1000) ...
# Generating image for seed 895 (895/1000) ...
# Generating image for seed 896 (896/1000) ...
# Generating image for seed 897 (897/1000) ...
# Generating image for seed 898 (898/1000) ...
# Generating image for seed 899 (899/1000) ...
# Generating image for seed 900 (900/1000) ...
# Generating image for seed 901 (901/1000) ...
# Generating image for seed 902 (902/1000) ...
# Generating image for seed 903 (903/1000) ...
# Generating image for seed 904 (904/1000) ...
# Generating image for seed 905 (905/1000) ...
# Generating image for seed 906 (906/1000) ...
# Generating image for seed 907 (907/1000) ...
# Generating image for seed 908 (908/1000) ...
# Generating image for seed 909 (909/1000) ...
# Generating image for seed 910 (910/1000) ...
# Generating image for seed 911 (911/1000) ...
# Generating image for seed 912 (912/1000) ...
# Generating image for seed 913 (913/1000) ...
# Generating image for seed 914 (914/1000) ...
# Generating image for seed 915 (915/1000) ...
# Generating image for seed 916 (916/1000) ...
# Generating image for seed 917 (917/1000) ...
# Generating image for seed 918 (918/1000) ...
# Generating image for seed 919 (919/1000) ...
# Generating image for seed 920 (920/1000) ...
# Generating image for seed 921 (921/1000) ...
# Generating image for seed 922 (922/1000) ...
# Generating image for seed 923 (923/1000) ...
# Generating image for seed 924 (924/1000) ...
# Generating image for seed 925 (925/1000) ...
# Generating image for seed 926 (926/1000) ...
# Generating image for seed 927 (927/1000) ...
# Generating image for seed 928 (928/1000) ...
# Generating image for seed 929 (929/1000) ...
# Generating image for seed 930 (930/1000) ...
# Generating image for seed 931 (931/1000) ...
# Generating image for seed 932 (932/1000) ...
# Generating image for seed 933 (933/1000) ...
# Generating image for seed 934 (934/1000) ...
# Generating image for seed 935 (935/1000) ...
# Generating image for seed 936 (936/1000) ...
# Generating image for seed 937 (937/1000) ...
# Generating image for seed 938 (938/1000) ...
# Generating image for seed 939 (939/1000) ...
# Generating image for seed 940 (940/1000) ...
# Generating image for seed 941 (941/1000) ...
# Generating image for seed 942 (942/1000) ...
# Generating image for seed 943 (943/1000) ...
# Generating image for seed 944 (944/1000) ...
# Generating image for seed 945 (945/1000) ...
# Generating image for seed 946 (946/1000) ...
# Generating image for seed 947 (947/1000) ...
# Generating image for seed 948 (948/1000) ...
# Generating image for seed 949 (949/1000) ...
# Generating image for seed 950 (950/1000) ...
# Generating image for seed 951 (951/1000) ...
# Generating image for seed 952 (952/1000) ...
# Generating image for seed 953 (953/1000) ...
# Generating image for seed 954 (954/1000) ...
# Generating image for seed 955 (955/1000) ...
# Generating image for seed 956 (956/1000) ...
# Generating image for seed 957 (957/1000) ...
# Generating image for seed 958 (958/1000) ...
# Generating image for seed 959 (959/1000) ...
# Generating image for seed 960 (960/1000) ...
# Generating image for seed 961 (961/1000) ...
# Generating image for seed 962 (962/1000) ...
# Generating image for seed 963 (963/1000) ...
# Generating image for seed 964 (964/1000) ...
# Generating image for seed 965 (965/1000) ...
# Generating image for seed 966 (966/1000) ...
# Generating image for seed 967 (967/1000) ...
# Generating image for seed 968 (968/1000) ...
# Generating image for seed 969 (969/1000) ...
# Generating image for seed 970 (970/1000) ...
# Generating image for seed 971 (971/1000) ...
# Generating image for seed 972 (972/1000) ...
# Generating image for seed 973 (973/1000) ...
# Generating image for seed 974 (974/1000) ...
# Generating image for seed 975 (975/1000) ...
# Generating image for seed 976 (976/1000) ...
# Generating image for seed 977 (977/1000) ...
# Generating image for seed 978 (978/1000) ...
# Generating image for seed 979 (979/1000) ...
# Generating image for seed 980 (980/1000) ...
# Generating image for seed 981 (981/1000) ...
# Generating image for seed 982 (982/1000) ...
# Generating image for seed 983 (983/1000) ...
# Generating image for seed 984 (984/1000) ...
# Generating image for seed 985 (985/1000) ...
# Generating image for seed 986 (986/1000) ...
# Generating image for seed 987 (987/1000) ...
# Generating image for seed 988 (988/1000) ...
# Generating image for seed 989 (989/1000) ...
# Generating image for seed 990 (990/1000) ...
# Generating image for seed 991 (991/1000) ...
# Generating image for seed 992 (992/1000) ...
# Generating image for seed 993 (993/1000) ...
# Generating image for seed 994 (994/1000) ...
# Generating image for seed 995 (995/1000) ...
# Generating image for seed 996 (996/1000) ...
# Generating image for seed 997 (997/1000) ...
# Generating image for seed 998 (998/1000) ...
# Generating image for seed 999 (999/1000) ...
# dnnlib: Finished run_generator.generate_images() in 1m 19s.

# %% [markdown]
# ### Style mixing, using the final snapshot

# %% [markdown]
# TODO repérer des "seeds" sympathiques

# %% [markdown]
# #### Without truncation

# %%
# !python stylegan2/run_generator.py style-mixing-example \
  --row-seeds=85,100,75,458,1500 \
  --col-seeds=55,821,1789,293 \
  --truncation-psi=1.0 \
  --network=results/{result_folder_name_to_load}/network-final.pkl \
  --result-dir='/content/drive/My Drive/results' \
# Out:
# Local submit - run_dir: /content/drive/My Drive/results/00058-style-mixing-example
# dnnlib: Running run_generator.style_mixing_example() on localhost...
# Loading networks from "results/00055-stylegan2-steam-1gpu-config-e/network-final.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# Generating W vectors...
# Generating images...
# Generating style-mixed images...
# Saving images...
# Saving image grid...
# dnnlib: Finished run_generator.style_mixing_example() in 17s.

# %% [markdown]
# #### With truncation

# %%
# !python stylegan2/run_generator.py style-mixing-example \
  --row-seeds=85,100,75,458,1500 \
  --col-seeds=55,821,1789,293 \
  --truncation-psi=0.5 \
  --network=results/{result_folder_name_to_load}/network-final.pkl \
  --result-dir='/content/drive/My Drive/results' \
# Out:
# Local submit - run_dir: /content/drive/My Drive/results/00059-style-mixing-example
# dnnlib: Running run_generator.style_mixing_example() on localhost...
# Loading networks from "results/00055-stylegan2-steam-1gpu-config-e/network-final.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# Generating W vectors...
# Generating images...
# Generating style-mixed images...
# Saving images...
# Saving image grid...
# dnnlib: Finished run_generator.style_mixing_example() in 17s.

# %% [markdown]
# ### Projection to latent space, using the final snapshot

# %% [markdown]
# #### Load all of the possible target images into a folder called `/content/256x256/`

# %% [markdown]
# Data consists of 14,035 vertical Steam banners, resized from 300x450 to 256x256 resolution.

# %%
colab_transfer.copy_file(file_name='256x256.zip')
# Out:
# Copying /content/drive/My Drive/256x256.zip to /content/256x256.zip

# %%
# !unzip 256x256.zip -d /content/

# %% [markdown]
# #### Move the target images into the folder expected by StyleGAN2

# %%
target_image_app_ids = [
                        570, # Dota 2
                        578080, # PLAYERUNKNOWN'S BATTLEGROUNDS
                        440, # Team Fortress 2
                        730, # Counter-Strike: Global Offensive
                        304930, # Unturned
                        550, # Left 4 Dead 2
                        4000, # Garry's Mod
                        240, # Counter-Strike: Source
                        10, # Counter-Strike
                        620, # Portal 2
                        400, # Portal
                        72850, # The Elder Scrolls V: Skyrim
                        271590, # Grand Theft Auto V
                        220, # Half-Life 2
                        105600, # Terraria
                        252950, # Rocket League®
                        60, # Ricochet
                        70, # Half-Life
                        863550, # HITMAN™ 2
                        292030, # The Witcher® 3: Wild Hunt
                        377160, # Fallout 4
                        8870, # BioShock Infinite
                        48000, # LIMBO
]

print('#images={}'.format(
    len(target_image_app_ids))
)
# Out:
# #images=23

# %%
# !mkdir -p /content/img/

for app_id in target_image_app_ids:
  # Reference: https://stackoverflow.com/a/40932507
  # !echo cp /content/256x256/{app_id}.jpg /content/img/
  # !cp /content/256x256/{app_id}.jpg /content/img/

# %% [markdown]
# #### Preparing datasets

# %%
# !python stylegan2/dataset_tool.py create_from_images '/content/datasets/real' '/content/img'
# Out:
# Loading images from "/content/img"
# Creating dataset "/content/datasets/real"
# Added 23 images.

# %% [markdown]
# #### Projecting images to latent space

# %%
# !python stylegan2/run_projector.py project-real-images \
 --data-dir='/content/datasets' --dataset=real \
 --num-images=23 \
 --network=results/{result_folder_name_to_load}/network-final.pkl \
 --result-dir='/content/drive/My Drive/results' \
 --num-snapshots=5 \
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 68
# Local submit - run_dir: /content/drive/My Drive/results/00060-project-real-images
# dnnlib: Running run_projector.project_real_images() on localhost...
# Loading networks from "results/00055-stylegan2-steam-1gpu-config-e/network-final.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# Downloading http://d36zk2xti64re0.cloudfront.net/stylegan1/networks/metrics/vgg16_zhang_perceptual.pkl ... done
# Loading images from "real"...
# tcmalloc: large alloc 4294967296 bytes == 0x4e0da000 @  0x7ff00b4e6001 0x7ff00900a765 0x7ff00906edc0 0x7ff009070c5f 0x7ff009107238 0x50ac25 0x50d390 0x508245 0x509642 0x595311 0x54a6ff 0x551b81 0x5a067e 0x50d966 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x58958c 0x5a067e 0x50d966 0x509d48 0x50aa7d 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x58958c 0x5a067e
# tcmalloc: large alloc 4294967296 bytes == 0x7fedcfb80000 @  0x7ff00b4e41e7 0x7ff00900a5e1 0x7ff00906ee88 0x7ff00906f147 0x7ff009107118 0x50ac25 0x50d390 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x50a080 0x50aa7d 0x50d390 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245
# tcmalloc: large alloc 4294967296 bytes == 0x7fedcfb80000 @  0x7ff00b4e41e7 0x7ff00900a5e1 0x7ff00906ee88 0x7ff00906f147 0x7fefcf034f05 0x7fefce9b8742 0x7fefce9b8cf2 0x7fefce971a7e 0x50a8af 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x5893bb 0x5a067e 0x50d966 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x509642 0x595311
# Projecting image 0/23 ...
# Projecting image 1/23 ...
# Projecting image 2/23 ...
# Projecting image 3/23 ...
# Projecting image 4/23 ...
# Projecting image 5/23 ...
# Projecting image 6/23 ...
# Projecting image 7/23 ...
# Projecting image 8/23 ...
# Projecting image 9/23 ...
# Projecting image 10/23 ...
# Projecting image 11/23 ...
# Projecting image 12/23 ...
# Projecting image 13/23 ...
# Projecting image 14/23 ...
# Projecting image 15/23 ...
# Projecting image 16/23 ...
# Projecting image 17/23 ...
# Projecting image 18/23 ...
# Projecting image 19/23 ...
# Projecting image 20/23 ...
# Projecting image 21/23 ...
# Projecting image 22/23 ...
# dnnlib: Finished run_projector.project_real_images() in 37m 18s.
